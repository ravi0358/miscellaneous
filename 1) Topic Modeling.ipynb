# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('TrustRadius web data.csv')

# %%
df.head()
# Out:
#                                         Review_Title  \
# 0                               Cisco Webex Meetings
# 1                        Cisco Webex Meetings Review
# 2  Cisco Webex Meetings for Meeting and Training ...
# 3  Webex Meetings will outshine the rest.....hand...
# 4                            Webex is #1 in my book!
#
#                                          Review_body  \
# 0  "I m",  using  Cisco  Webex  Meetings  almost ...
# 1   Our  organization  relies  on  Cisco  Webex  ...
# 2   Cisco  Webex  Meetings  is  used  for  our  d...
# 3   We  use  it  across  the  entire  org  and  i...
# 4   I  started  using  the  personal  one  when  ...
#
#                                          Review_pros  \
# 0   During  troubleshooting  sessions, "I m",  ab...
# 1   Easy  to  use  Has  better  features  Recordi...
# 2   Simplicity  Many  features  Easy  to  use  In...
# 3   One  button  to  push  joining.  Just  having...
# 4   Easy  implementation  Webex  well  known  thr...
#
#                                          Review_cons Review_date  \
# 0   Sound  quality  during  meetings  when "I m",...    4-Sep-20
# 1       I "don t",  see  any  cons  at  this  time.    31-Aug-20
# 2   Sharing  file  using  Webex  Meetings  Bandwi...   24-Aug-20
# 3   The  back  end  management  of  users  CAN  b...    7-Apr-20
# 4   After  permission  is  given  for  keyboard/m...   28-May-20
#
#     User_Rating      Customer_Name                     Position  \
# 0  10 out of 10    Joacim Wicander  Senior Data Center Engineer
# 1  10 out of 10  Zar Jerome Cajudo              System Engineer
# 2   9 out of 10       Budi Ezeddin  Senior Technical Specialist
# 3  10 out of 10      Joshua Baever    Sr. Systems Administrator
# 4   9 out of 10        Sandt Brian         System/DB/UCCE Admin
#
#                         IndustryType Number 0f Employees
# 0  Information Technology & Services    51-200 employees
# 1                             Retail  501-1000 employees
# 2  Information Technology & Services   201-500 employees
# 3                 Telecommunications   10,001+ employees
# 4             Hospital & Health Care  501-1000 employees

# %%
import re
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext


def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

        
decontracted(df['Review_Title'][1]+' ' +df['Review_body'][1])
# Out:
# 'Cisco Webex Meetings Review  Our  organization  relies  on  Cisco  Webex  Meetings  to  provide  remote  support  to  our  clients.  If  there  are  issues  raised  by  our  client  we  send  a  Webex  invite  to  further  troubleshoot  the  issue.  We  also  use  Cisco  Webex  Meetings  whenever  there  are  meetings  and  bidding  for  a  project.  The  business  problem  that  it  addresses  is  providing  an  easy  way  of  collaborating  with  other  employees  and  our  customers. '

# %%
from tqdm import tqdm
stopwords= ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't", 'dominar','bajaj','explain','bike']

preprocessed_title = []
# tqdm is for printing the status bar
for sentance in tqdm((df['Review_Title']+' ' +df['Review_body']).values):
    sent = decontracted(sentance)
    sent = cleanhtml(sent)
    sent = sent.replace('\\r', ' ')
    sent = sent.replace('\\"', ' ')
    sent = sent.replace('\\n', ' ')
    sent = re.sub('[^A-Za-z0-9]+', ' ', sent)
    # https://gist.github.com/sebleier/554280
    sent = ' '.join(e for e in sent.split() if e.lower() not in stopwords)
#     print(sent)
    preprocessed_title.append(sent.lower().strip())
preprocessed_title
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1579/1579 [00:00<00:00, 7875.37it/s]
# ['cisco webex meetings using cisco webex meetings almost daily meetings colleagues customers colleagues meeting rooms host meetings necessary even hold training sessions colleagues via cisco webex meetings reason except covid reasons use cisco webex meetings much work home takes 2 hours drive closest office cisco webex meetings really useful partake kinds internal meetings',
#  'cisco webex meetings review organization relies cisco webex meetings provide remote support clients issues raised client send webex invite troubleshoot issue also use cisco webex meetings whenever meetings bidding project business problem addresses providing easy way collaborating employees customers',
#  'cisco webex meetings meeting training purposes cisco webex meetings used day day meeting training used entire organization employees mobile also work branches customer offices need reliable way meetings communication using webex meetings give presentations customers well saves lot time cost sure',
#  'webex meetings outshine rest hands use across entire org supports everyone videoconferencing needs especially virus outbreak rely heavily still solution allows us meeting joins audio video screen sharing 60 seconds addressed problem many different hardware software solutions confusing user base one primary source people business users using dropping older technologies like skype business teams switching webex meetings conferencing needs',
#  'webex 1 book started using personal one company interested webex pricing since negotiated new maintenance contracts able slip money purchase licenses begun implementing internally organization using prem skype received many complaints choppy calls not able share documents no issues personal webex account championed purchase company',
#  'cisco webex go collaboration tool not always go using cisco web ex across entire organization helps us collaborate not internally externally employees customers vendors saved us travel customer locations well remote sites using cisco web ex video endpoint devices greatly improved video conferencing capabilities',
#  'cisco webex meetings review application used entire organization since useful tool terms communication even times pandemic social distancing necessary area problems addressed equipment failures reviews conjunction areas well cisco supplier',
#  'cisco webex providing solid meeting foundation enterprise cisco web ex meetings used across company drive customer internal meetings utilize service existing video infrastructure enhance collaboration drive productivity provides company global solution accessible pc mobile perspective providing wide range flexibility joining meetings disperse workforce',
#  'webex meetings company 60 company using web ex meetings video conferencing service moved everyone company remote work time covid 19 begun utilize even using personal rooms teams staff video meetings tend run bandwidth issues 60 employees video meeting smaller group seems work fine part role executive assistant schedule lot meetings others not attend downside webex schedule meeting not make attendees host not start meeting unless sign feature caused quite bit frustration scrambling get new dial number past overall webex meetings need',
#  'cisco webex meetings review used across whole organization useful join meetings anywhere e office home without special hardware join laptop mobile devices',
#  'use webex meetings use webex internal external video conferencing needs whole organization alleviates connections internal external clients',
#  'webex good use webex hold digital meetings ease use huge ability share documents using audio video makes feel like room many features hard pick one definitely tool used size organization',
#  'great journey cisco webex meetings review enable cisco webex meetings executives department supervisors allows contact many customers save time cisco webex meetings gives opportunities reach clients shows company really modern cisco webex meetings could used many devices systems users clients able join meetings many ways many situations',
#  'easy use started using webex 1 month ago lockdown easily organise office meetings easily communicate help application use software weekly need personal meetings',
#  'honest opinion cisco webex meetings know covid 19 made huge problem society damaged education systems lot find better solution solve problems company decided use webex meetings almost classes lot students said webex great app able solve communication problems pandemic situation conclusion almost staff students use app love',
#  'cisco webex review using cisco webex meetings across organization daily meetings internal departments clients',
#  'amazing experience using cisco webex meetings amazing platform audio hd video conferences screen sharing best user interface excellent individual chat option good collaboration participants meetings made easy cisco webex meetings easy schedule meetings automatically added calender use whiteboard showcase thoughts clients record discussions save later use never issues tool like no advertisements meetings',
#  'cisco webex review used remote support customers meeting vendors customers outside company country training',
#  'satisfied webex user using meeting platform inside company stopped using zoom started use webex security reasons',
#  'cisco webex meetings cisco webex meetings used bring together employees located different cities face face meetings also using webex customer interaction time social distancing',
#  'webex meetings easy use use cisco webex meetings internally externally support customers via webex meetings',
#  'best product online meetings present unprecedented increase remote work happening organization due circumstances resulting covid 19 coronavirus disease cisco webex meetings helps us meet communicate collaborate home remote locations webex one stop shop meetings webex single tool handle meetings helps us devote time taking care core business',
#  'webex beyond cisco shop use cisco webex meetings time courthouses departments works general town hall meetings site well',
#  'easy meetings cisco webex meetings used whole organisation schedule web audio meetings customers',
#  'great product use cisco webex meetings throughout organization great collaboration tool teams cuts travel helps current covid 19 issues',
#  'cisco webex meetings review cisco webex meetings meets demand remote troubleshooting easy gui control workstations also rest assured connection secured integration outlook email calendar plus greatest benefit use phone audio call also app version webex really comes handy go mobile recommend screenshot function great resolution recording dependent internet connection kind slow philippines',
#  'cisco webex meetings core enterprise collaboration webex meetings used company core infrastructure collaboration scope deployment global 15 000 users every business product development sales admin organizations use webex daily basis conduct internal external meetings',
#  'webex experience use webex meetings pretty much every day communication colleagues used entire company efficiently improved communication efficiency among team members especially given covid situation everyone work home collaborate remotely since not able go onsite quarterly meeting cisco webex playing vital role ensuring important big meetings held scheduled turn helps maintain corporate business operations',
#  'cisco webex meetings easy secure option cisco webex meetings used entire institution departments daily basis meetings conferences clinical activities addresses web conferencing opportunities team meetings consultations within institution community preferred method communication chosen institution integrated business email quick access',
#  'easy secure meetings used department safe secure meeting alternative',
#  'secure best quality cisco webex meetings used day day core business conducted subsidiaries clients meetings video conferencing presentation sharing biggest advantage assured consistent reliable cost effective secure meeting experience',
#  'business continuity webex meetings webex meetings 1 global conferencing solution internal external audio video content sharing smaller teams townhall meetings starting prem webex using cloud service days covid 19 reliable video solution working home becomes even important',
#  'solution every meeting everywhere home company trip cisco webex used 2 way audio video meetings companies extend collaboration use cisco webex meetings across whole organisation allow every user benefit power webex cisco webex meetings resolve problem computer compatibility network problem no need admin computer execute',
#  'cisco webex review used across whole company allows users quickly schedule calls meetings without wasting travel time cab costs important app use anywhere anytime allowing us work anywhere screen share another great use case webex helps share docs work collaboration customers',
#  'average webex user used department heavily support many teams business analysts also use support international staff connect vendors weekly meetings instead site meetings saves time resources normally would spend going person meetings instead attending meeting desk',
#  'high quality product company chose go another way mostly use webex meetings working support desks outside company assisting issues tried various solutions house including zoom go meeting webex company recently moved using microsoft teams',
#  'positive secured platform collaboration utilize trusted source web conferencing dealing external agencies house solution inter business unit needs however dealing external partners cisco webex go',
#  'best conference solution businesses cisco webex used primary video conference solution across organization end users well meetings customers solves need users interact among internal teams customers without needing travel',
#  'webex review webex used whole organization solves business problems team communication time expense travel conference calling collaboration team members aids physical distancing',
#  'cisco webex meetings review use business specifically day day operations meeting socializing helps current pandemic education use move distance learning helps current pandemic',
#  'great meetings technical support using webex meetings b2b clients also used remote support sessions reduces cost going client office makes us productive sales force',
#  'cisco webex web meeting not microsoft teams using widely need participate meetings employees external collaborators order accomplish jobs meant done internally urgent need teleworking covid 19 company extra need video conference online meetings webinars',
#  'safe video conferencing cisco webex two year ago started work webex users use tool users not culture using video conferencing events covid 19 users realized platform discuss quickly easily started using webex currently webex used average 18 22 hours day gradually increasing users started use different features recording webinar',
#  'okay whole organization uses help discuss problems customers',
#  'webex user review provides synchronous capabilities distance learning univ',
#  'cisco webex meetings review used across whole organization collaboration',
#  'webex use meetings remote collaboration especially sharing content meetings',
#  'cisco webex meetings review use webex meetings conduct training clients every day connection clarity good system also used across departments',
#  'cisco webex meetings review use webex meetings default web meeting application across entire organization primarily used meetings 2 25 users occasional training collaboration larger audiences',
#  'cisco webex review use cisco webex meetings simple conference calls well screen share collaboration presentation meetings others inside outside organization solves problem communicating others remotely different time zones gives us ability work better partners outside organization',
#  'best meeting tool small groups austin community college typically use webex meetings across school various meetings use virtual appointments students well weekly team meetings among staff faculty also used view monthly advising forums advisors cannot meet specific campus day',
#  'technology overcomes barriers en volkswagen ocupamos mucho webex para conferencias exposiciones ex menes para compartir toda la informaci n entre varias reas generar comunicados de valor para todos los socios mismo es una herramienta que se ha utilizado con mucha frecuencia ya que nos permite actualizarnos compartimos informaci n nuevas soluciones volkswagen often use webex conferences exhibits exams means sharing information different offices generating valuable communication stakeholders used frequently allows us update share information new solutions',
#  'solid product speed troubleshooting sessions cisco webex meetings used senior execs sales services people extensively troubleshooting demos quarterly meeting also webex associated go numbers quarter question answer sessions often recorded archived cannot attend live',
#  'journey cognitive collaboration experience greif cisco webex meetings one stop solution conferencing needs used sharing presentations audio conferences web conferences well integration 60 room systems integrate collaboration room option added experience daily calls weekly team updates project kickoff meetings get done one user experience environment greif embarked ambitious upgrade path replace upgrade cloud register endpoints 2020 exciting project opening doors upcoming enhancements cisco queue',
#  'best best standard meeting platform customer meetings demonstrations collaboration',
#  'webex solid solution online meetings use webex meetings online market research interviews easy use set great recording feature use often',
#  'cisco webex meetings review started cisco webex meetings company implement cisco components network started work cisco webex communicate many parties host meetings different parties different locations around world usually used top management traveling needed communication',
#  'webex meetings offers best experience meetings currently used throughout organization optimizing issue needing instantly meet customers',
#  'simple high quality communication tool cisco webex meetings widely used within organization simple platform offers great experience video calls screen sharing marketing department use time remotely interview students applying internships department webex meetings best communication means facilitate interviews video audio usually great quality make us satisfied using platform',
#  'let meet cisco webex meetings cisco web ex meetings used organization carrier appointments webinars us learn products one platforms use allows individuals around country able access information provided easy platform use',
#  'good option somewhat expensive used throughout organization streamline meetings well make official announcements ceo',
#  'effective collaboration tool use cisco webex meetings collaboration tool across entire breadth company used anything small 2 3 person meetings departmental meetings involving dozens team members allows us single place meet online across multiple sites using video audio',
#  'cisco webex best field without doubt ford motor company along jvs joint ventures like ford otosan ford sollers stakeholders employees cisco webex meeting users connect via ford webex com invite associates like suppliers dealers well honestly speaking primary source running whole meetings whether premises across locations involved meantime thanks features like easy dialing connecting via videocall audio mobile call makes life even easier parties',
#  'webex meetings easy use global organizations webex meetings used entire organization address need meeting clients absence site visits helps us build maintain good relationships clients since team scattered globally makes easier us organize bring together team support clients needs',
#  'let meet via webex org currently using webex meetings across whole organization whole webex gives us flexibility users able participate office many staff mobile giving option meet go allows org agile well efficient',
#  'cisco webex makes life easy engineer use cisco webex order discuss themeswith partners traveling venezuela difficult time remote conferencesmake difference interface simply wonderful 3 clicks areall done us webex powerful tool incident resolution becauseengineers around world get platform configure things withoutany complication',
#  'cisco rocks unified communications using cisco webex meetings meetings different vendors across world found smooth error free voice video content sharing',
#  'collaboration made easy cisco webex webex board s55 municipality guayaquil city use web ex meetings across 5 departments directions call combination cisco webex boards local governmental entity mainly use web ex establish communication collaborate partners providers even provide us technical support within organization',
#  'webex meetings passes test sido un gran beneficio ya que acortado distancias facilitado las videoconferencias reduciendo costos de traslado optimizando tiempos para ser mas efectivos con esto logramos estar mas cercar de nuestras sucursales dar un mejor servicio acercamientos nuestros colaboradores grandes rasgos sido una gran ayuda great benefit since metaphorically shortened distances offices facilitated video conferences reducing travel costs efficient time manage work closely various offices provide better services approaches collaborators huge help',
#  'wow webex cisco webex meeting used company reduce travel increase productivity no longer travel customer sites fix customer faults able give great customer experience aspects support internally use face face meetings video device work attitude helps meeting participants stay focused get subject hand',
#  'nice work agile methodologies used use daily standup meetings since work using scrum methodology',
#  'webex meetings best way organize manage meetings webex meetings used entire organization easily say almost default tool daily communication use communicate not colleagues different regions within company also suppliers service providers outside company use schedule meetings share information meetings broadcast information review status summary one useful tools used far within organization',
#  'cisco webex meetings review use webex meetings hold presentations clients partners also use webinars never problem',
#  'webex worldwide cisco webex meetings collaboration tool sites future change cisco webex teams',
#  'webex meetings awesome deployed webex across whole organisation everyone create host meetings place time addresses less traveling lowers travel costs joining high quality virtual meetings ad hoc cooperation sessions needed able create meetings directly mail system really easy timesaving',
#  'start join meetings quickly easily used across whole organization allows us start join meetings quickly easily schedule start join meetings desktop directly microsoft outlook meet online crisp clear video audio conferencing share screen present information annotate shared documents whiteboards',
#  'cisco webex meetings review national company use product make different locations',
#  'webex day day office video needs currently use product meet one one students distance learners used campus wide variety reasons one one purposes office find ways connect distance learners help meet sanction requirements needed web ex helps us meet goal providing platform see students face face virtually',
#  'teleconferencing click webex meetings utilized within organization organize meetings internally well customers support allows easy conferencing facilitating great communication members team additionally ability create room users call view control remote screen critical helping engineers debug customer issues',
#  'webex meetings pleasant positive alternative meetings webex meetings currently used team managers meeting employees within company addresses certain issues within company alternative skype business adobe connect platform user friendly presents positive interaction opinion colleagues knowledge not everyone uses webex meetings',
#  'virtual meetings device time single click cisco webex meeting used users company human resources administration entire technical commercial area since meetings suppliers colleagues clients even distance interviews needs surveys sales support multiple use cases webex meetings problems solving tool',
#  'webex best webex virtual meeting platform easy use reliable record meetings attend even conduct meetings away desk phone tablet majority vendors use webex plug play sharing content information really care much sharing cam others turn not bad',
#  'webex works used webex connect department regular meetings people attending meetings spread either home across city countries used not share voice call also allow offsite folks join virtually makes meeting productive get interact team not listen',
#  'excellent tool virtual meeting high quality video voice use webex one main channels communication especially helpful team members work remotely almost meetings conducted webex even room meetings also configure webex team members not really need join attend via webex usually quick direct discussion team members using web ex saves lot effort helps speed progress webex flexible organizing meetings schedule meeting open private room quick discussion supports kind devices windows mac android ios not require software installation',
#  'cisco webex communicate easily cisco webex meetings used calls customers cisco verizon etc send us invite meeting accept log call customer meetings last 1 hour approximately someone usually shares screen',
#  'webex devices cisco webex devices used organization several customers helping us create unique meeting experiences',
#  'webex experience used mostly hr help desk departments important tool collaboration within users also support collaboration business associates outside organization hr uses webex training interviewing purposes',
#  'webex meetings powerful ally webex meetings used throughout organization support team marketing team etc gives us possibility meeting coworkers clients prospects place space time practically device eliminates physical barriers allowing us virtual office able attend important matters receive visits',
#  'webex review used across whole organization meetings',
#  'cisco power use webex meetings connect users throughout world',
#  'use webex remote teams use webex way communication guys dev ops team russia colombia',
#  'palace resorts cisco webex used across whole company virtual rooms cisco spark',
#  'cisco webex great tool could easier use expensive el problema es que no es tan amigable el precio no es competitivo al menos contra zoom problem not user friendly price not competitive least zoom',
#  'webex good webex interesting tool use organization use everything virtual meetings focus remote education employees es una herramienta muy interesante que llegamos usar en la organizacion todo lo que tenga que ver con reuniones virtuales enfocado la educacion distancia los colaboradores',
#  'great experience using cisco webex meetings collaboration use communicate remote employees host meetings across different offices',
#  'new super great method communicating use weekly meetings people outside office also easier connect supervisors may travelling using webex meetings outside weekly meetings use pretty often casual communication',
#  'webex meetings great audio used presentations throughout company host conferences',
#  'webex meeting user webex meetings used conferences parent company regular user webex meetings well used entire parent company verizon offers quick connection either video audio desktop mobile easy use 25 users offers ability mute everyone required',
#  'good conferencing currently use collaboration among teams well online learning lectures not required webex used online course offerings many faculty embrace others still prefer discussion board format teaching courses team collaboration pockets departments use webex time others still prefer person meetings',
#  'like product need couple enchancements everyone company uses cisco webex meetings used meetings people country across globe use internal meetings well meetings customers',
#  'quick easy conferencing cisco webex meetings used across entire institution provide access virtual online meetings web conferences user schedule host meetings others inside organization also outside organization online meetings accessed users desktop pcs macs mobile devices campus video conferencing systems',
#  'not intuitive attendees simplification potential webex mostly used screen sharing purposes 1 users traditional conference call problem solves providing ability share something visual another party walking someone presentation either dictated users client 4 host accounts users need schedule meetings organization attended webex guest host accounts not specific department task mostly frequent needs screen sharing video conferencing',
#  'webex primary method use online meetings found meet needs comes video conferencing team often uses many different meetings members team different places feature rich works well needs',
#  'not problem host presentation whole company need great meeting tool move meetings real life online webex deliver webex promising delivering quality years constantly updating software get better years nowadays mobile version big improvement users tend use mobile devices like tablets mobile phones',
#  'great meeting platform really easy use specially useful companies remote teams cisco webex meetings primary virtual meeting solution across company employees access webex meetings well webex teams majority employees work remotely webex helps us stay connected team clicks organize meetings whole team',
#  'amazing collaboration webex webex used across organisation support effective communication collaboration team members based remotely across different countries used place physical meetings utilising video conferencing functions make colleagues feel though room together likewise collaborative functions enabling meeting recordings sharing screens mutual viewing ability work one document multiple meeting attendees makes project management monitoring straightforward us',
#  'difficult use unreliable used across whole organization last company online meetings used basic webex meetings first also tried using webex teams scheduling hosting meetings meant address meetings partially house partially remote company',
#  'review fan webex work consulting company many different clients manage communicate current client stationed uses webex across whole organization allows easy communication sharing ideas helps bring offshore teams contact onshore teams convenient way',
#  'webex meeting client closer contact use tool hold meetings business partners suppliers customers answer questions resolve questions project always great tool hands employees also use support customers',
#  'great product virtual meetings used across whole organization used team meetings presentations recordings virtual attendees non fda employees site international',
#  'webex great meeting tool support many users webex used throughout whole organization standard meeting platform users use employees teams located different regions webex provides space meetings take place support 300 end users webex feature rich addresses many business concerns organization solved question collaborate different areas globe',
#  'webex meetings review used use webex meetings lot another carrier found user friendly everyone used great large meetings involving multiple offices still allowing hands work',
#  'great around product meeting conference needs internal external currently webex meetings used within department across entire company use internal external meetings employees clients customers reliable easy use understand everyone great handling small large attendee calls presentations helps remote employees feel included day day office proceedings',
#  'cisco webex meetings online meetings finest organization experienced issues communicating clients countries cisco webex decreased gap meetings able get done currently used management team want expand usage across organization know cisco webex lot cool things use implement meeting rooms however invest implement need prove business case internally',
#  'hassle free way conduct long distance meetings cisco webex used making conference calls enables screen sharing without delay offers high quality voice transfer solves communication problem not inside company colleagues also partners different time zones',
#  'great tool share audio visuals use program meetings share audio visual aspects computers colleagues work different sites well outside organization suppliers used entire organization comes default program work computers provided employee easy set meeting share link within outlook',
#  'cisco webex easy connect conduct use cisco webex devices run seminars department regular group meeting experts collaborating us outside department use cisco webex device connect useful department run kind meeting',
#  'italian webex user used particular department meeting international users partners cisco webex meetings allows meetings independently pcs devices used end user small support needed department',
#  'roads lead webex use webex meetings primary webinar collaboration tool across organization tried variety platforms due cost webex end moved back webex meetings due stability ease use provides issues outside users installing client platforms times available webex meetings seems work',
#  'webex ex reason used webex meetings host webinars 100 500 members within organization webinar featured slides speakers video screen sharing',
#  'webex meetings best web conference tool used webex used across organization pretty cool find reliable compared meeting tools also url generic easily connect audio various ways screen sharing good helps us quickly talk people remotely',
#  'webex meetings tool need online meetings using meetings scheduled basis using tool screen sharing work staff different projects applications well using webex meetings long time staff enjoy ease working tool gives us ability meetings no matter far away someone',
#  'cisco webex video communications tool today use cisco webex meetings meetings external partners need screen sharing enables communication otherwise would unavailable outside face face meeting',
#  'cisco webex meetings review tool helped lot improve communication work teams remotely since tools great difficulty connect due licenses domains company recommendation would add option transfer files means complete 100 satisfaction user experience',
#  'cisco webex meetings solid product many users across organization end users webex meetings set parties not many people situation webex meeting provider initiator webex meeting initiated department',
#  'webex meetings review cisco webex meetings used organization collaborate meet share information internally externally peers partners customers also use general conference calls whiteboarding polling needed cisco webex meetings addresses need stay connected agile way without much overhead',
#  'webex great tool collaborate use cisco webex time need share ideas knowledge define objectives develop projects organization tools important share points views get results asap',
#  'far used used meetings coworkers spain',
#  'webex meetings review use cisco webex hold attend online meetings collaborate team projects share documents addition useful allows us record capture meetings held facilitate business discussions distance remote meetings saving time travel costs',
#  'conferencing go web ex allows talk customers set design reviews share screen',
#  'webex nothing peers nothing less unless skimped license webex used organization primarily online meetings involve screen share currently phased company favor microsoft teams meeting licensing agreement webex portion users able use integrated audio well users access screen sharing portion telephony handled separate conference bridge',
#  'webex meetings great platform remote collaborations presentations current company webex meetings currently used large meetings need include employees not onsite sharing content external collaborators sometimes internally screen share sometimes combination reasons internal meetings sometimes include large training sessions personally helped include employees work offsite home need attend group meetings',
#  'webex meetings reliable easy use great quality webex meetings used across organization used internal meetings meetings include external partners meetings include customers telemedicine use across various types devices smartphones workstations tablets higher end cisco meeting rooms',
#  'webex experience use webex contact partners clients also used technical support principal support tool',
#  'webex meeting decent cloud solution cloud conferencing remote support many using webex meeting cloud conferencing bridge video conference also give remote support customers deliver training sessions customers internal employees using webex meeting center hr uses webex meeting center conduct interview candidates sales review calls happen webex conference recording needed',
#  'one stop shop webex meetings become one used products company public saftey department used officers meet remotely without need come office fire department able meet several times month without need moving fire trucks ambulances since moving vehicles causes lot problems response times cost webex saved us whole lot money',
#  'great collaboration product business webex meetings used across whole organization use primarily meetings sharing content internally externally engineering also specific use cases primary one remote control troubleshooting customers',
#  'webex meetings great used across organization benefits us making us agile saving time money travel central locations',
#  'love video conferencing used across whole organization wish departments would get board able meet moments notice scheduled meetings nice room kit mini tie webex really nice get whole conference room worry laptop going sleep end table',
#  'stay productive connected webex webex meetings used conduct meetings clients employees partners not located immediate area makes easy communicate across company current potential business clients everyone company uses time time main user ceo business meetings',
#  'good online meeting program webex company online meeting system using since 2013 like product setting meeting joining meeting webex easy especially using one click button outlook way need arrange many things seconds meeting arranged good international meetings',
#  'subpar service virtual company online conferencing lifeblood web ex product buggy service horrendous audio calls randomly start sounding robotic took 8 attempts email phone get reply account manager every time issue submit ticket takes 2 days someone get back long meeting far worst service support experienced technology platform licensed thought go wrong going well known brand turns wrong',
#  'webex meetings must bridge gaps individuals work together different locations webex meetings used enterprise wide organization conduct conference video calls closes distances businesses allowing us live face face discussions organization global without tool webex would travel often attend certain meetings',
#  'easy way meeting use webex meetings within whole organization helps saves travel cost also able connect organizations low cost used struggle lot assisting business meetings outside organization senior managers executive board members happy since purchased webex licenses',
#  'webex press ideas easier web ex used primarily marketing department fielding creative development requires voice phone correspondence',
#  'webex best connecting tool recording sharing anything transitioned skype meetings recently currently transition webex used along couple tools several years used webex prior coming jdi not mention multiple sessions outside jdi currently targeted internal users webex login use use host remote meetings conference calls training sessions record pertinent partner meetings applicable',
#  'webex meetings collaboration web ex meetings used throughout company helped create great collaboration experience clients see recommend video ability us share desktop webex definitely great way keep clients satisfied process able schedule meetings quickly',
#  'webex way forward webex used whole organization means holding team meetings not people based different parts uk also field sales reps',
#  'webex meetings gold standard teleconferencing collaboration webex meetings primary collaboration platform used organization used across whole organization meetings conference calls remote support sessions',
#  'webex helps teams sizes thrive used whole organization helped us remote meetings internally well customers compared solutions easy use elegant solution able save hundreds hours compared person meetings',
#  'excellent use webex often educational activities cisco academy instructor conferences classes certify helped lot problems related communications country',
#  'webex like organization uses web ex internal meetings customer meetings presentations routinely not day goes not consulting internal associate external customer web ex',
#  'webex adequate communication tool quickly outpaced market use web ex need connect remote party speaker live broadcast need distribute audio content user base viewing one broadcasts occasionally use collaborating pre post production meetings well content meetings clients',
#  'cisco webex meetings brings collaboration everyone utilize webex meetings internal external collaboration employees vendors used daily basis small stand meetings members different locations also used larger meetings rich content sharing video needed',
#  'webex online meetings use webex within ford across globe online meetings withing company suppliers customers third parties done webex',
#  'webex ultimate unified conference solution use webex unified conferencing solution across organization provides unified collaboration experience users audio web video recording white boarding content sharing features single package thus eliminating need different standalone platforms provided either one features allowed users join meetings anywhere anytime wide range joining options',
#  'webex evaluation use collaborate institutes universities whether simple phone call video bridge',
#  'webex corporate webex integrated heavily daily lives use support individual users support entire facilities emergency calls 500 users best part webex meetings availability private rooms recording work go back later date',
#  'webex meeting review end user using webex meetings whole company main video conference method used internal meetings meetings vendors customers providers works well sharing screen content time people see remotely',
#  'great option restricted industries needing local server web ex premise used communicate internal external users using pure meeting format sometimes taking control user pc support purposes premise versions not capable cloud versions due restrictions financial services industry company way things selected option worked well small deployment',
#  'great conferencing solution use webex main conferencing platform distance learning meetings take place meeting center although use training events well little use support center whole organization uses webex conferencing also see use reservation less audio conferencing portion platform',
#  'work made easy web ex meetings used sales team various purposes like training within team system dumps collection customers presentation customers traveling vendor system demos feature capability helps us stakeholders one meeting talk face face no one required travel pan india team discuss different solutions share views one go',
#  'webex meetings bluejeans alternative deployed webex meetings blue jeans replacement besides offering us option license user university including students faculty staff gives us perks coupled spk edu offering cisco never owned licensing nearly comparable blue jeans meeting tight integration webex teams actively deploying webex teams entire university fall',
#  'webex meetings strict vendor access policy place dictates access vendors monitored member network services team webex meetings allows us quickly set meeting grant access vendor maintaining security change management control also use webex meetings conference collaborate partners design review new software also used allow remote users access quarterly adhoc staff meetings saving mileage labor costs commute otherwise would travel corporate office',
#  'webex still winner web ex replacement legacy microsoft live meeting skype business install used across entire organization corporation solves performance issues vendors partners solutions zoom blue jeans etc',
#  'webex meetings great collaboration best market entire organization uses daily internal client facing meetings',
#  'webex great virtual meetings nan',
#  'great tools lacks exceptional audio quality webex meetings used daily whole organization helps us schedule important meetings discuss issues immediately without need meet person show participants issues',
#  'pricey worth large webinars mostly use web ex meetings external clients used across whole organization variety domestic international clients allows us conduct large scale webinars fairly stable platform distribute recordings webinars internal external stakeholders needed',
#  'easiest way setup meeting webex meetings default application within company conduct meeting whether working remotely office able use web app download stand alone app join meeting simple solution straightforward works flawlessly every time setting joining meeting could not easier',
#  'job would nearly impossible without webex meetings webex meetings used across entire organization entire organization uses makes easy set meetings confirm attendance share screens complete conference calls entire organization understands etiquette using webex functionality easy catch webex meetings addresses business problems inconvenient meeting tactics making less time needed travel set conference call numbers time discussions get work done',
#  'connecting world webex meetings used online meetings among different departments within company suppliers outside company used across company webex meeting resolves complicated issue meet face face use modes also helps minimizing telephone bills oversees meetings',
#  'one best collaboration virtual meeting tools market webex meetings used nearly entire team within business primary tool organizing holding virtual meeting partners customers without leaving location perfect presentations meetings even simple chat feeling webex provides quite immersive gives feeling meeting rooms client tool used computers smartphones tablets',
#  'pretty good conference softwate cisco webex meetings currently used entire company use tool video conference across departments also meet people outside company first tool like webex meetings implementation video conferencing became something easy everyone',
#  'quick overview webex meetings use webex meetings large group meeting wish guarantee compatibility across different teams external organisations',
#  'best conferencing app quality problems intercontinental calls use prem solution got complaints executives webex meetings solves quality problems dynamic quality control',
#  'webex meetings great tool immensely useful used across entire organization means effectively collaborate colleagues users outside company',
#  'webex wonderful tool made easy webinars company rolling new products really enjoy ease use intuitive design',
#  'webex meetings great tool enterprise collaboration used across entire organization allowed remote offices able join meetings view presentations live video increased collaboration',
#  'virtual meeting room webex meetings used whole organization external teams suppliers across world thing like easily share meeting room link people quick meeting either select call call connect via computer dial additionally use webex mobile app useful office join meeting',
#  'glad back web ex used primarily three departments across organization training used weekly online webinar training series account management used daily system support one one training clients sales used multiple times month system demos',
#  'webex meetings remote support use web ex meetings support departments software vendors purchased products used teams view screen get temporary remote access assist troubleshooting issues implementations products also use web ex user feedback sessions companies',
#  'webex functional meetings multiple devices organization uses web ex remote meetings allows us include participants not able attend person participants call phone join computers laptops makes giving information join meeting easy example providing link calling code etc',
#  'great software easy use use web ex meetings hold participate meetings one largest customers big 3 automotive manufacturer allows us share information anywhere world web ex used within department project management',
#  'great meeting tool east use used north american branch company helps us communicate internally group setting also used external meetings remotely experience used mostly externally facing clients customers easy use',
#  'webex tech guru meeting platform web ex scattered throughout organization previous organizations worked web ex integrates well variety services physical platforms use allowing us singular platform collaborate platform really solves question actively collaborate share remote employees allowing us quickly create meetings fly sharing',
#  'traditional safe choice not intuitive organization used web ex meetings much video audio conferencing needs within organization external clients located sides country clients dispersed across us overseas allowed us communicate relatively easily',
#  'webex go wrong used web ex meetings ad box meetings internally well external screen sharing presentations also consulted companies web ex use',
#  'cisco webex easy going solution meeting collaboration enterprises fantastic experience use tool mainly used conducting online meetings group chat video chats remote training purpose yes used whole organization working perfectly fine like wide variety features like presenter control screen sharing recording etc',
#  'webex best platform meetings use mainly meetings remote team members currently used departments whenever want global call often go web ex meetings easy use connectivity makes us choose go option meetings',
#  'new webex not grandpa conference suite remote meeting becoming norm campuses expand across world additionally asked less less people less money less time accomplish task workload ever increasing host web ex meeting number colleagues across nyc maximize time no travel stay point agenda recording meeting show later folks absent training last point must',
#  'trusted webinar provider easy use web ex meetings great tool allows businesses communicate exchange information globally conference calls webinar platforms used interface many times perform live meetings trainings presentations interface easy use not overly complicated would recommend platform new users',
#  'experience webex meeting software used across organization useful comfortable tool manage web meeting especially technical screen sharing activities',
#  'webex meetings solid product used enterprise work lots international employees therefore helps bridge gap virtual work also helps us collaborate projects software ability share documents etc',
# ...
#  'duo security perfect 2fa answer use duo two factor authentication applications like vpn outlook web access everyone vpn account access email externally account spreads across several different departments internal also use two factor servers remote desktop',
#  'zero 2fa quickly easily duo security simple low friction way solve problem compromised accounts organization dozens dozens users would fall phish surrender passwords hackers would access accounts use purposes duo solved problem even users gave away passwords 2fa solution prevented hackers accessing accounts amazing painless implement much moving toward rolling students well',
#  'duo two factor authentication easy fast duo security provides two factor authentication security measure online resources many resources contain personal private information including patient information hospital employees duo user friendly application seamlessly connects users work accounts using phones another layer security employees university utah required use duo log accounts',
#  'end user perspective seems relatively easy duo security used verify logins company vpn authenticator application across entire organization prevent unauthorized access',
#  'duo security simple mfa solution used across entire organization multi factor authentication used authenticate servers require bit security well access network externally using vpn ties well current infrastructure authentication purposes allows users easily access network click button whilst helping us enhance security posture',
#  'well thought integrated two factor authentication solution choice implementing duo security made limit impact accounts compromise users institution core focus roll two factor authentication community users access critical data staff faculty contractors student workers currently covered duo security use solution access services goal roll solution entire student population help better protect information limit impact accounts compromised rest community',
#  'amazing security product duo 2fa best feature implemented throughout company secure connections easily duo push well manage end user access easily duo mobile provides 2nd form factor authentication variety ways flexible using app phone receive push notifications receive call system receive text integration various systems straightforward simple part knowing bad actor not steal credentials obtain user mobile device information gives sense done realistically user enrollment management breeze best news affordable protection',
#  'duo protects business user logins protect users effects hacked accounts duo used every user company provide stronger login security office computers servers access corporate portal number applications like drupal',
#  'easy use configure mfa contender implemented duo security employee internet facing applications multi factor authentication necessity current world moment adfs integration running smoothly duo integrated vpn solution enterprise password manager great satisfaction admins users',
#  'great cloud mfa solution duo security 2fa solution use several systems remote access vpn sso duo offers several 2fa options including push phone call text today 2fa must authentication duo need hardware tokens mobile phone',
#  'home run windows mfa used dev ops staff require multi factor authentication mfa logins windows servers addition security measure great practice implement anyway mfa one items payment card industry data security standards pci dss',
#  'duo security extra layer implemented duo security organization beta test see something clients would able use whole organization uses adds another layer security top layers already good solution business looking tighten security',
#  'duo love duo security used across whole organization seamless easy use addressed need 2 factor authentication way impact users',
#  'quick facts duo security anyone remote access firm access dupo needs two factor authentication',
#  'mfa without hiccups say duo security made life users lives better not seamless product use implement least sonicwall sra office 365 carbon black works without hiccups pretty much set forget top gives simple huge extra layer security need network terms multi factor authentication mfa',
#  'duo safeguards data duo used provide secure access company information via access cloud apps behind multi factor authentication protects company emails',
#  'duo great easy use tool use two factor authentication externally facing cloud based applications deploy users needs services remote desktop owa salesforce screen connect like helps secure organization credential theft via brute force attacks phishing like love end user experience log need pull phone pull app text message code enter touch push notification hit approve button logged',
#  'duo easy user adoption duo security used two factor authentication outside connectivity internal resources across entire organization including third party vendor access support services users use duo app phones support vendors use key fob purchased specifically two factor authentication obviously much safer external access',
#  'duo security 2 factor authentication works duo security used 2 factor authentication method accessing server locally remotely via ssh especially true linux based servers contain mission critical functions sensitive data enables admin users access systems need keeping intruder users also solved real issue around vpn users required 2 factor authentication build necessities lock network outside intrusion simple mistake end user accidentally write share credentials defeat efforts team made duo security also viable specific use cases vpn access administration access servers working conjunction radius server use hardware tokens well mobile 2 factor text messages list ready use applications easy setup extensive well documented duo security authentication proxy not easiest integrating network however installed working everything sort fell place',
#  'best 2fa software duo security used whole organization addresses core authentication issue user traceability',
#  'duo factor authentication duo currently used increase security administrative systems sensitive information used mostly not exclusively within internal staff also tested working well part login process f5 glb apm virtual desktop infrastructure',
#  'duo dual easy intuitive used duo across organization dual factor authentication solution vpn remote desktop logins intuitive user interface push notifications gave us safe easy use solution ensuring safety security information employees clients companies sensitive information',
#  'duo security offers best class protection best class ease use use duo security enterprise 2 factor authentication 2fa system loyola university maryland currently protect remote application delivery system well share point portal office 365 implementation duo departments also additional uses computer science department protects remote linux unix ssh access duo department protects password vault duo',
#  'rest easy feel secure duo security duo security used provide second form factor authentication remote access corporate information either citrix cisco vpn used authorized user across enterprise controlled membership specific active directory group duo security addressed need ensure access resources specifically emr granted authorized individuals',
#  'right 1st time duo security duo security provides excellent solution band authentication duo also allows manage multiple applications across duo platform expand oob authentication',
#  'duo fantastic next generation multifactor platform ideally gap came implementing multi factor solution looking one easy employees use easy implement low support overhead duo fit criteria',
#  'duo security use anything else duo security used across durst organization means authenticate users attempting log remote desktop server outlook web application client duo security critical security measure ensure appropriate users logging system not office machines connected domain',
#  'great security product already place duo used entire organization whole use sso organization strongly duo 2 factor provider gives us extra layer security teams organization',
#  'duo thumbs two step authentication duo allows entire company successfully access specific tools require two step authentication helps protect company potential hacking attempts ups security sensitive information also makes easy users complete two step authentication limits time spent trying complete task like opening email hunting security code waiting text message authenticate',
#  'duo effective simple reliable two factor authentication use staff secure authentication whether email saa applications utilize duo make sure limit potential unauthorized access',
#  'duo simple fast use multi factor authentication critical systems used across organization full time employees well contractors even cases customers helps us mitigate potential compromise issues user names passwords adds additional layer security additionally pretty low impact users productivity',
#  'security taken seriously use duo security across organizations logging network take security seriously enabled second factor authentication recently internal users even lan duo integrates well modes mediums push comes handy remember one time token easy install simple even switch mobile effective secured',
#  'hooray duo use duo security let staff access people soft oracle function used departments university since dealing student grades student money want make sure whoever granted access system tracked one 4 administrators system far working well plan implement faculty also people still reluctant use cell phone 2 factor authentication used offer landline phone respective department',
#  'cisco anyconnect review cisco connect allows secure connections able access resources company safe fast simple way guarantees us stable connection necessary time easy install without complications end users even no experience area technology addition affordable solution',
#  'cisco anyconnect currently organization uses cisco connect connect employees remote manage conjunction cisco identity services engine ise scenario easy administer currently 300 simultaneous sessions per day asa 5580 useful tool comes developing vpns user groups integrating ad duo perfect remote security combination vpn',
#  'cisco anyconnect review cisco connect usually used engineering team use technology connected time no matter critical service management running cisco connect cisco strong reliable products',
#  'easy connect anyconnect following covid 19 let workers work home moment not possible connect remotely company systems implement remote connection system quickly cisco connect came picture within day implemented system set security settings allowed users organization connect home work environment',
#  'great vpn solution company uses cisco connect connect company network working home anywhere outside office allows users access files network folders connecting home wi fi networks even coffee friends nearest coffee shop',
#  'cisco anyconnect perfect vpn solution remote access corporate network advanced security use cisco connect connect corporate network via vpn establishes secure tunnel endpoint device laptop mobile corporate network uses 256 bit aes encryption data connection remains secure vpn firewall policies company applies incoming outgoing data endpoint malicious attacks websites prevented vpn connection allows user access internal storage server company vpn connection reliable stable secure cisco connect uses multi factor authentication establishes connection legitimate users connect corporate network',
#  'feel free anyconnect way connect used company wide allowed access resources internally otherwise would require users onsite would need seek alternative methods remote work accessing services securely connected network avails us not large attack surface fewer services public',
#  'end user review cisco anyconnect cisco connect used organization remote work solution even encountered pandemic allowed us access resources use work remote site due number reasons within professional scope course unfortunate times became useful allowed us continue day day business importantly support customers well',
#  'cisco anyconnect review engineer perspective using cisco connect primary vpn tool allows employees remotely work especially unfortunate pandemic access internal tools servers day day operations includes terminal servers web servers provisioning servers likes well reporting tools sales generation cmdb administration clicks internal corporate network allows us jobs responsibilities comfort safety may add home offices collaboration centric company boosted credo working together everywhere propelled collaboration services terms internal use well outward facing serve beloved customers',
#  'tiny tool provide optimum secure connections cisco connect used entire company create secure connections order log company intranet confidential services web pages portals secret confidential information kept company private networks secure connection required login cisco connect provides connection mobility client may called vpn well',
#  'cisco anyconnect review use cisco connect able manage equipment different locations road quick easy use easy enough non technical users get running',
#  'cisco anyconnect review cisco connect using multiple reasons one connect ssl outside company company network users needs access internal servers applications usage handling authentication ise security compliance devices connect network',
#  'best vpn solution ever never go wrong cisco using connect connect pcs company network users working home around 20 workforce working home office',
#  'cisco anyconnect thin client works cisco connect company choice vpn connection corporate network used sales teams remote employees user needs access corporate network outside company site many tools require access corporate network vpn solution like cisco connect vital business',
#  'cisco anyconnect great vpn software cisco connect used whole company computers pads smartphones tablets use vpn get inside private network not connected work wi fi field working remotely',
#  'ciscoanyconnect not questions answers remote access organization currently uses deploys cisco connect majority client locations exception new locations budget higher concern mainly utilized data security teams remote access clients networks consulting capacity',
#  'cisco anyconnect vpn client cisco connect used employees contractors across globe access internal resources additionally used allow connect pc windows apple mobile device apple android configuration policy centrally managed easy deploy changes globally connect solves lot problems connecting resources contractors anyconnect well known market lot consultants know',
#  'anyconnect works cisco connect used company virtual private network vpn access well part cisco umbrella client monitor websites visited',
#  'desktop support tech review cisco anyconnect cisco connect used company wide help users connect resources available network',
#  'great visibility support protection anyconnect time connect used across organization 10 countries offers added vpn security essential company particularly team grows travels across regions',
#  'secure reliable vpn application connect application installed notebooks supplied company reliable easy use use whenever office require connect work network configure different equipment hop multiple networks within organisation authentication challenged active directory logins',
#  'good secure vpn access protected networks use cisco connect secure remote access internal networks employees managed endpoints remote work culture product enables business mobile still able access applications infrastructure cannot internet facing',
#  ...]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
no_features = 1000

# %%
tfidf_vectorizer  = TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(preprocessed_title)
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

# %%
tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(preprocessed_title)
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
from sklearn.decomposition import NMF,LatentDirichletAllocation
no_topics = 20

# %%
nmf = NMF(n_components=no_topics,random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print ("Topic %d:" % (topic_idx))
        print (" ".join([feature_names[i]
                         for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 10

# %%
display_topics(nmf, tfidf_feature_names, no_top_words)
# Out:
# Topic 0:
# catalyst series 3850 9300 switches 9400 9200 9500 cisco 6800
# Topic 1:
# meetings webex used organization cisco collaboration review customers sharing internal
# Topic 2:
# access point cisco aironet points review 1815 wifi benefits remote
# Topic 3:
# jabber phone tool communication organization chat instant office messaging used
# Topic 4:
# series cisco 3800 2800 aironet aps ap 1815 1850 best
# Topic 5:
# 2960 catalyst xr series switch cx 3560 reliable 2960x review
# Topic 6:
# routers cisco isr locations core asr used routing review edge
# Topic 7:
# ex web meetings used screen organization share allows webinars sharing
# Topic 8:
# duo security authentication factor access 2fa organization secure used applications
# Topic 9:
# teams webex collaboration cisco team collaborate using tool communicate helps
# Topic 10:
# asa firewall vpn cisco network security connect site used using
# Topic 11:
# wireless controllers lan cisco aps guest points wlcs meraki access
# Topic 12:
# meraki mx switches manage firewalls firewall network ms cloud locations
# Topic 13:
# wan sd mpls network sites cisco solution branches cost availability
# Topic 14:
# center dna contact cisco unified network data product solution assurance
# Topic 15:
# meeting webex virtual company app using best outlook software travel
# Topic 16:
# umbrella dns cisco protection protect filtering security internet organization review
# Topic 17:
# 3650 catalyst series reliable cisco 3850 review robust predictable secure
# Topic 18:
# room video conference conferencing rooms kit solution audio endpoints calls
# Topic 19:
# use support users great easy connect remote webex company tool

# %%
display_topics(lda, tfidf_feature_names, no_top_words)
# Out:
# Topic 0:
# executives associated configuring cyber complicated conversation boards applications code distribution
# Topic 1:
# cisco aids compatible established enfocado analysis console eliminates commute conjunction
# Topic 2:
# 80 approval absence 1200 approve dar approximately businesses 1560 comunicacion
# Topic 3:
# dig executive authentication brands devote completely dozens designed customers 2800
# Topic 4:
# edge download events competitive changing attorneys comunicaci esto desktop dual
# Topic 5:
# enabled dmvpns cam config contributed distances basically adieu dmvpn 9400
# Topic 6:
# dual auditoriums compartir conjunction assistance audiences business bills capacity asked
# Topic 7:
# deal cisco competitors dictated designs coming convenient admin accepted changer
# Topic 8:
# becauseengineers cli damaged away combination consume backbone conduct developing capable
# Topic 9:
# established compatible energy enfocado aids console establish compatibility edifier believe
# Topic 10:
# deploy asas aids cisco enable context allowing banking cross decent
# Topic 11:
# compatible asa established complete coming entry attending carriers 2020 acl
# Topic 12:
# backbone cli consume damaged enabling clinical austin configure compare execute
# Topic 13:
# cisco conversation arise distribution delivering conferencesmake block del calls cognitive
# Topic 14:
# authorized accounting blades 2500 engine 9400 choosing esto 1540 certification
# Topic 15:
# academy elegant beats 9400 absent conectado consulted 3650 efficiency apis
# Topic 16:
# 802 computers automated consulted compatibility common closely assistance broad accomplish
# Topic 17:
# aids energy conferencias 22 competitivo deployment enfocado dial everyday especially
# Topic 18:
# difficult advisors aids 1530 eases 18 execs 5506 2000 16
# Topic 19:
# corporate clean daily caused centers coworker compatible conectarnos cual aids
