# %%
import pandas as pd
import numpy as np
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
import dateparser

# %%
df = pd.read_csv('C:/All/Data/reviews.csv')

# %%
df.head()
# Out:
#                                   title  \
# 0                Worst bike dominar 400
# 1       The fashionable-- bajaj dominar
# 2         Not as shown in advertisement
# 3  Don't buy dominar 400 or bajaj bikes
# 4             Servicing and maintenance
#
#                                          description  ratings sentiment  \
# 0  Chain sound is very loud after riding 1500km i...        1       neg
# 1  <p>Hi, this bajaj dominar is very good. It has...        3       neg
# 2  I have test driven it,it is not like shown in ...        1       neg
# 3  Bajaj's quality is so bad as compared to other...        1       neg
# 4  I have dominar bike, this is 1 year old bike r...        1       neg
#
#      source date_posted
# 0  bikewale  25-03-2019
# 1  bikewale  25-04-2018
# 2  bikewale  25-04-2018
# 3  bikewale  25-12-2018
# 4  bikewale  25-11-2018

# %%
import re
def cleanhtml(raw_html):
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', raw_html)
    return cleantext


def decontracted(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

        
decontracted(df['title'][1]+' ' +df['description'][1])
# Out:
# 'The fashionable-- bajaj dominar <p>Hi, this bajaj dominar is very good. It has great experience to ride. It is nice and comfortable to ride. Great to buy and as far as looks is concern it is very glamorous and shiny. Its servicing and maintenance is also good and handy at places. So overall it is good to buy this bike.And maintenance is also awesome. So ride well and safely and protect your life with helmet and follow traffic rules.</p>'

# %%
from tqdm import tqdm

# %%
stopwords= ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've",\
            "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', \
            'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their',\
            'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', \
            'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', \
            'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', \
            'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after',\
            'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further',\
            'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more',\
            'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', \
            's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', \
            've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn',\
            "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn',\
            "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", \
            'won', "won't", 'wouldn', "wouldn't", 'dominar','bajaj','explain','bike']

preprocessed_title = []
# tqdm is for printing the status bar
for sentance in tqdm((df['title']+' ' +df['description']).values):
    sent = decontracted(sentance)
    sent = cleanhtml(sent)
    sent = sent.replace('\\r', ' ')
    sent = sent.replace('\\"', ' ')
    sent = sent.replace('\\n', ' ')
    sent = re.sub('[^A-Za-z0-9]+', ' ', sent)
    # https://gist.github.com/sebleier/554280
    sent = ' '.join(e for e in sent.split() if e.lower() not in stopwords)
#     print(sent)
    preprocessed_title.append(sent.lower().strip())
preprocessed_title
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 1369/1369 [00:00<00:00, 2287.13it/s]
# ['worst 400 chain sound loud riding 1500km lube chain lubricant also yamaha r15 v3 not faced problem v3 like chain noise lots vibrations worst ever 1 80lakh go ktm 390 pay extra 90 thousand much better worst machine',
#  'fashionable hi good great experience ride nice comfortable ride great buy far looks concern glamorous shiny servicing maintenance also good handy places overall good buy maintenance also awesome ride well safely protect life helmet follow traffic rules',
#  'not shown advertisement test driven not like shown add troll royal enfield not good performer weight less body hard transmission royal enfield much much better one using enfield legacy sale vehicle problem silencer getting holes sometime use no stability not suitable person height handle congested',
#  'not buy 400 bikes quality bad compared bikes not proper engineers team service centres terrible ride lots bikes found brakes not good even dual channel abs scrap not work well service partner not even know service chain set bad body quality bad every 4 5 days u tight chain bolt specially handle lock start shacking lots noises coming body service centres not able solve problems take 1 2 week give without anything average poor lots unnecessary sounds makes irritate owner guys not buy u get irritate service partners every week u visit service centres not anything complaints',
#  '400 last week purchased 400 nearest dealer purchased good looks good features powerful good mileage comfort fuel tank 13 litres 373cc single cyclinder built top speed 155km h bik',
#  'budget product exotic power budgetd product great power would say budget no avilable used really liked comes 373 cc enough rider really loved ita enough ride lot still didnt fell spinal p',
#  'awesome name name performence bajaja 400 ver good bick brothe recently brought ride picup simply awesome really got sexy desing really looks good motion smouth',
#  'dominor 400 ride not get feel riding sports appearance rider comforts move fast good pick not convinient stunting pulsar 200ns since high centre gravity compared pulsar 200ns ba',
#  'adinath gade family gifted 400 brother birthday sports great power mileage also good best comfort best control road grip also good make good feel sound great go ride sunday thi',
#  'good look 400 hi friends 400 power cruise 400cc bikes rs 1 45 lakhs perfect look power extraordinary dual handed abs system sleepper clutch mostly suitable long rides ride slightly give',
#  '400cc impactable series poduct totally different product maintenance osm develops osm variation sound cost better not bad bikes like duke etc type look like ktm duke 200 b',
#  'dominor 400 pros stylish per manual see design based male lion thick mane around head sounds refined sounds likes sports rev best head light seen cons seating rear seat literally worst seat',
#  '400 super guys new 400cc best market trending features simply amazing nstalled abs technology known anti lock breaking system abled 2 tube less tyres gives pretty good',
#  '400 october 2017 dubbed spanish word means access 400 brings pranks youtube full form users comfort horrible fun run machine launched december 2006 capable characters presented affordable power cru',
#  'superb 2017 hi guys motocompany lauched new new dominor 400 recently market thr sold market beacsue looked design excllent quality looking sexy lookedthe bulid quality good design lookinh awesome',
#  'beast not mileage truly really beast guarantees good road grip awesome comfortness superb road trips mileage not good otherwise really good purchase looks suspension engine braking system top notch 400cc beast always ensure',
#  'dominor 400 hello firends recently purchase dominor 400 good looking ever milage poor company says 35 40 high way try 30 km per litter bile graphics good style attractive engine power full pick high balanced',
#  'era power riding quite bikes owned friends couple years reading magazines watching countless videos tube ready purchase first wanted make sure bought perfect anything tough find',
#  ...]

# %%
(df['title']+' ' +df['description']).values
# Out:
# array(["Worst bike dominar 400 Chain sound is very loud after riding 1500km i lube the chain with the lubricant  and i have also a yamaha r15 v3 i don't have faced any problem in my v3 like chain noise.  it's only bajaj and lots of vibrations in my dominar worst bike ever in 1.80lakh   go for ktm 390 .  Pay extra 90 thousand and much more better than this worst machine dominar.",
#        'The fashionable-- bajaj dominar <p>Hi, this bajaj dominar is very good. It has great experience to ride. It is nice and comfortable to ride. Great to buy and as far as looks is concern it is very glamorous and shiny. Its servicing and maintenance is also good and handy at places. So overall it is good to buy this bike.And maintenance is also awesome. So ride well and safely and protect your life with helmet and follow traffic rules.</p>',
#        'Not as shown in advertisement I have test driven it,it is not like shown in add where they troll royal enfield" this bike is not good performer.Weight less body very hard transmission.Royal enfield is much much better that this one.They are using enfield legacy to sale there vehicle.After all bajaj has problem with silencer getting holes after sometime of use.No stability,not suitable for person with height.Handle are very congested.',
#        ...,
#        'Stunning An exceptional bike has been launched by bajaj finding 400 cc bike in this range is quit rare apart from that tourque upto 8000rpm is quite disappointing 200ns has the same torque in low range, the design is quite good but technical features may explain anything but the build quality is impressi...',
#        'FASTEST BAJAJ Amazing 400cc bike. Best competitor for KTM Duke 390. It is almost a lakh lesser than duke, but gives good performance when compared. Still Duke is winner. Comfort riding posture and good for cruising. To be frank dominar is worth the price, all the other bikes in the same segament is more than ...',
#        "Bajaj dominar 400 I have been riding this bike since last 2 months. Overall good performance. Feels great when you ride on highway. Easily crosses 100 KM per hr without any vibration. Dominar deserves more sales, it's n awesome bike. Test rode one today and was blown away fantastic torque. Comfortable riding post..."],
#       dtype=object)

# %%
text_data=[]
for i in range(len(preprocessed_title)):
        tokens=preprocessed_title[i].split()
        text_data.append(tokens)

# %%
text_data
# Out:
# [['worst',
#   '400',
#   'chain',
#   'sound',
#   'loud',
#   'riding',
#   '1500km',
#   'lube',
#   'chain',
#   'lubricant',
#   'also',
#   'yamaha',
#   'r15',
#   'v3',
#   'not',
#   'faced',
#   'problem',
#   'v3',
#   'like',
#   'chain',
#   'noise',
#   'lots',
#   'vibrations',
#   'worst',
#   'ever',
#   '1',
#   '80lakh',
#   'go',
#   'ktm',
#   '390',
#   'pay',
#   'extra',
#   '90',
#   'thousand',
#   'much',
#   'better',
#   'worst',
#   'machine'],
#  ['fashionable',
#   'hi',
#   'good',
#   'great',
#   'experience',
#   'ride',
#   'nice',
#   'comfortable',
#   'ride',
#   'great',
#   'buy',
#   'far',
#   'looks',
#   'concern',
#   'glamorous',
#   'shiny',
#   'servicing',
#   'maintenance',
#   'also',
#   'good',
#   'handy',
#   'places',
#   'overall',
#   'good',
#   'buy',
#   'maintenance',
#   'also',
#   'awesome',
#   'ride',
#   'well',
#   'safely',
#   'protect',
#   'life',
#   'helmet',
#   'follow',
#   'traffic',
#   'rules'],
#  ['not',
#   'shown',
#   'advertisement',
#   'test',
#   'driven',
#   'not',
#   'like',
#   'shown',
#   'add',
#   'troll',
#   'royal',
#   'enfield',
#   'not',
#   'good',
#   'performer',
#   'weight',
#   'less',
#   'body',
#   'hard',
#   'transmission',
#   'royal',
#   'enfield',
#   'much',
#   'much',
#   'better',
#   'one',
#   'using',
#   'enfield',
#   'legacy',
#   'sale',
#   'vehicle',
#   'problem',
#   'silencer',
#   'getting',
#   'holes',
#   'sometime',
#   'use',
#   'no',
#   'stability',
#   'not',
#   'suitable',
#   'person',
#   'height',
#   'handle',
#   'congested'],
#  ['not',
#   'buy',
#   '400',
#   'bikes',
#   'quality',
#   'bad',
#   'compared',
#   'bikes',
#   'not',
#   'proper',
#   'engineers',
#   'team',
#   'service',
#   'centres',
#   'terrible',
#   'ride',
#   'lots',
#   'bikes',
#   'found',
#   'brakes',
#   'not',
#   'good',
#   'even',
#   'dual',
#   'channel',
#   'abs',
#   'scrap',
#   'not',
#   'work',
#   'well',
#   'service',
#   'partner',
#   'not',
#   'even',
#   'know',
#   'service',
#   'chain',
#   'set',
#   'bad',
#   'body',
#   'quality',
#   'bad',
#   'every',
#   '4',
#   '5',
#   'days',
#   'u',
#   'tight',
#   'chain',
#   'bolt',
#   'specially',
#   'handle',
#   'lock',
#   'start',
#   'shacking',
#   'lots',
#   'noises',
#   'coming',
#   'body',
#   'service',
#   'centres',
#   'not',
#   'able',
#   'solve',
#   'problems',
#   'take',
#   '1',
#   '2',
#   'week',
#   'give',
#   'without',
#   'anything',
#   'average',
#   'poor',
#   'lots',
#   'unnecessary',
#   'sounds',
#   'makes',
#   'irritate',
#   'owner',
#   'guys',
#   'not',
#   'buy',
#   'u',
#   'get',
#   'irritate',
#   'service',
#   'partners',
#   'every',
#   'week',
#   'u',
#   'visit',
#   'service',
#   'centres',
#   'not',
#   'anything',
#   'complaints'],
#  ['servicing',
#   'maintenance',
#   '1',
#   'year',
#   'old',
#   'running',
#   'km',
#   '14000',
#   'tyre',
#   'specialty',
#   'front',
#   'tyre',
#   'put',
#   'complaint',
#   'resolve',
#   'concern',
#   'satisfied',
#   'product',
#   'problem',
#   'coming',
#   '14000',
#   'km',
#   '40000',
#   'km',
#   'running',
#   'understand',
#   'unresolved'],
#  ['worst',
#   'engineered',
#   'year',
#   '2017',
#   '1',
#   'buying',
#   'experience',
#   'average',
#   'dealers',
#   'usually',
#   'cheaters',
#   'lot',
#   'golmals',
#   'gimmicks',
#   'one',
#   'careful',
#   'times',
#   'try',
#   'sell',
#   'test',
#   'drive',
#   'bikes2',
#   'not',
#   'feel',
#   'like',
#   '400',
#   'cc',
#   'owned',
#   'apache',
#   '160',
#   'performance',
#   'pickup',
#   'far',
#   'superior',
#   'compared',
#   'domineer3',
#   'looks',
#   'like',
#   'big',
#   'not',
#   'translate',
#   'performance',
#   'poorly',
#   'designed',
#   'need',
#   'visit',
#   'show',
#   'room',
#   'twice',
#   'week',
#   'not',
#   'reliable',
#   'longer',
#   'run',
#   'want',
#   'hassle',
#   'free',
#   'life',
#   'better',
#   'avoid',
#   '4',
#   'servicing',
#   'poor',
#   'none',
#   'service',
#   'center',
#   'guys',
#   'know',
#   'repair',
#   'maintain',
#   'maintenance',
#   'poor',
#   'chain',
#   'sprocket',
#   'chain',
#   'needs',
#   'frequent',
#   'replacement5',
#   'pros',
#   'looks',
#   'cons',
#   'fuel',
#   'injection',
#   'always',
#   'problemmileage',
#   'always',
#   'problemcity',
#   'riding',
#   'amount',
#   'generated',
#   'heat',
#   'cook',
#   'food',
#   'tandoori'],
#  ['chain',
#   'sounds',
#   '13kmpl',
#   'mileage',
#   'great',
#   'power',
#   'takes',
#   'us',
#   'heaven',
#   'provides',
#   'least',
#   'comfort',
#   'since',
#   'like',
#   'bikes',
#   'also',
#   'chain',
#   'problem',
#   'disturbing',
#   'noise',
#   'chain',
#   'even',
#   'smooth',
#   'ride',
#   'offers',
#   'less',
#   'mileage',
#   'get',
#   'mileage',
#   '13',
#   'kmpl',
#   'positive',
#   'side',
#   'speed',
#   'offer',
#   'price',
#   'better',
#   'ktm',
#   'best',
#   'performance'],
#  ['super',
#   'performance',
#   'not',
#   'catch',
#   'eyeballs',
#   'road',
#   'buying',
#   'experience',
#   'overall',
#   'good',
#   'one',
#   'riding',
#   'technically',
#   'good',
#   '400cc',
#   'abs',
#   'led',
#   'headlamp',
#   'set',
#   'main',
#   'problem',
#   'not',
#   'catch',
#   'eyes',
#   'road',
#   'royal',
#   'enfield',
#   'ktm',
#   'moreover',
#   'sounds',
#   'like',
#   '125',
#   'cc',
#   'could',
#   'taken',
#   'design',
#   'also',
#   'ktm',
#   'going',
#   'sell',
#   'one',
#   'upgrade',
#   'duke',
#   '250',
#   'thunderbird',
#   '500x'],
#  ['nothing',
#   'beat',
#   'bought',
#   'month',
#   'ago',
#   'first',
#   'everything',
#   'okay',
#   'better',
#   'riding',
#   'experience',
#   'completely',
#   'satisfied',
#   'state',
#   'confusion',
#   'weather',
#   'buy',
#   'new',
#   'opted',
#   'completely',
#   'happy',
#   'not',
#   'bought',
#   'image',
#   'front',
#   'friends',
#   'later',
#   'long',
#   'trip',
#   'friends',
#   'felt',
#   'ride',
#   'bore',
#   'uncomfortable',
#   'back',
#   'start',
#   'paining',
#   'ride',
#   'around',
#   'approx',
#   '30',
#   '45',
#   'km',
#   'one',
#   'stretch',
#   'feel',
#   'uncomfortable',
#   'feel',
#   'difficult',
#   'things',
#   'okay',
#   'brakes',
#   'stuff',
#   'maintenance',
#   'also',
#   'fine',
#   'not',
#   'much',
#   'headache',
#   'whatever',
#   'nothing',
#   'beat',
#   'done',
#   'mistake',
#   'opted'],
#  ['not',
#   'buy',
#   'dominor',
#   'bought',
#   'new',
#   '2',
#   'months',
#   'driving',
#   'tire',
#   'blasted',
#   'alloy',
#   'wheel',
#   'also',
#   'got',
#   'damaged',
#   'quality',
#   'pathetic',
#   'apart',
#   'contacted',
#   'showroom',
#   'popular',
#   'showroom',
#   'mandya',
#   'mysore',
#   'service',
#   'response',
#   'bad',
#   'funny',
#   'thing',
#   'asking',
#   'claim',
#   'insurance',
#   'instead',
#   'helping',
#   'neglecting',
#   'would',
#   'suggest',
#   'not',
#   'buy',
#   'bikes',
#   'understand',
#   'within',
#   '2',
#   'months',
#   'tire',
#   'blast',
#   'think',
#   'condition',
#   '2',
#   'years'],
#  ['not',
#   'buy',
#   'not',
#   'want',
#   'write',
#   'review',
#   'suggest',
#   'not',
#   'buy',
#   'many',
#   'good',
#   'bikes',
#   'less',
#   'cost',
#   'no',
#   'trained',
#   'service',
#   'centres',
#   'poor',
#   'mileage',
#   'hell',
#   'issues',
#   'would',
#   'not',
#   'recommend',
#   'shit',
#   'no',
#   'one',
#   'lot',
#   'issues',
#   'vibrant',
#   'vibes',
#   'low',
#   'quality',
#   'system',
#   'switches',
#   'original',
#   'place',
#   'also',
#   'engine',
#   'shit',
#   'typical',
#   'engine',
#   'disturbance',
#   'face',
#   'soon',
#   'switch',
#   'rpm',
#   'not',
#   'constant',
#   'varies',
#   'every',
#   'time',
#   'dangerous',
#   'riding',
#   'gear',
#   'box',
#   'gear',
#   'levers',
#   'tend',
#   'get',
#   'stuck',
#   'really',
#   'hard'],
#  ['400',
#   'idiocracy',
#   'best',
#   'beast',
#   'avid',
#   'traveler',
#   'rider',
#   'would',
#   'like',
#   'particularity',
#   'good',
#   'decent',
#   'mileage',
#   'take',
#   'roads',
#   'terrains',
#   'places',
#   'without',
#   'hiccups',
#   'talking',
#   'hiccups',
#   'comes',
#   'deal',
#   'breaker',
#   '400',
#   'no',
#   'doubt',
#   'cheapest',
#   '400cc',
#   'till',
#   'date',
#   'india',
#   'worst',
#   'someone',
#   'said',
#   'particularly',
#   'bikes',
#   'not',
#   'trustworthy',
#   'not',
#   'agree',
#   'statement',
#   'buying',
#   'experience',
#   'riding',
#   'experience',
#   'different',
#   'vision',
#   'look',
#   'hate',
#   'statement',
#   'dominate',
#   'road',
#   'even',
#   'dominate',
#   'road',
#   'consumers',
#   'hell',
#   'lot',
#   'fuel',
#   'gives',
#   'average',
#   'mileage',
#   '20kmpl',
#   'worst',
#   'imagine',
#   'accept',
#   'coming',
#   'duke',
#   '390',
#   '400',
#   'big',
#   'no',
#   'would',
#   'not',
#   'recommend',
#   'shit',
#   'no',
#   'one',
#   'lot',
#   'issues',
#   'including',
#   'vibrant',
#   'vibes',
#   'low',
#   'quality',
#   'plastics',
#   'abs',
#   'braking',
#   'issues',
#   'brakes',
#   'applied',
#   'switches',
#   'original',
#   'place',
#   'low',
#   'quality',
#   'tire',
#   'hugger',
#   'also',
#   'engine',
#   'shit',
#   'notice',
#   '6months',
#   'riding',
#   'typical',
#   'engine',
#   'disturbance',
#   'face',
#   'soon',
#   'switch',
#   'rpm',
#   'not',
#   'constant',
#   'varies',
#   'everytime',
#   'dangerous',
#   'riding',
#   'gear',
#   'box',
#   'gear',
#   'levers',
#   'tend',
#   'get',
#   'stuck',
#   'really',
#   'hard',
#   'not',
#   'want',
#   'complain',
#   'experience',
#   'also',
#   'coming',
#   'later',
#   'part',
#   'sales',
#   'service',
#   'done',
#   'kanchan',
#   'wagle',
#   'estate',
#   'not',
#   'complain',
#   'engineers',
#   'no',
#   'use',
#   'serviced',
#   'called',
#   'service',
#   'center',
#   'collect',
#   'tell',
#   'issues',
#   'facing',
#   'including',
#   'vibrations',
#   'tried',
#   'fixed',
#   'could',
#   'not',
#   'brakes',
#   'no',
#   'struggle',
#   'braking',
#   'well',
#   'even',
#   'not',
#   'fixed',
#   'answer',
#   'big',
#   'no',
#   'someone',
#   'looking',
#   'hyperride',
#   'like',
#   '400',
#   'would',
#   'definitely',
#   'recommend',
#   'not',
#   'go',
#   'online',
#   'reviews',
#   'instead',
#   'check',
#   'fellow',
#   'riders',
#   'friends',
#   'owns',
#   '400',
#   'try',
#   'test',
#   'every',
#   'bit',
#   'wish'],
#  ['thinking',
#   'buy',
#   'see',
#   'review',
#   'name',
#   'tell',
#   'everything',
#   'engine',
#   'not',
#   'durable',
#   'talk',
#   '35',
#   'hp',
#   '35',
#   'nm',
#   'also',
#   'see',
#   'weight',
#   'around',
#   '180kg',
#   'power',
#   'weight',
#   'ration',
#   'less',
#   'know',
#   'indian',
#   'companies',
#   'use',
#   'low',
#   'grade',
#   'material',
#   'never',
#   'like',
#   'paint',
#   'sticker',
#   'also',
#   'cheap',
#   'quality',
#   'logo',
#   'chrome',
#   'rub',
#   'easily'],
#  ['worst',
#   'world',
#   'terrible',
#   'dominars',
#   'engine',
#   'issue',
#   'first',
#   'day',
#   'facing',
#   'also',
#   '400',
#   'absvery',
#   'harsh',
#   'behaviour',
#   'showrooms',
#   'workshops',
#   'officers',
#   'unprofessional',
#   'staffs',
#   'better',
#   'buy',
#   '3rd',
#   'hand',
#   'purchase',
#   'first',
#   'hand',
#   '400',
#   'abs'],
#  ['turning',
#   'radius',
#   'disappointing',
#   'also',
#   'avenger',
#   'cruise',
#   'disappointing',
#   'taken',
#   'test',
#   'ride',
#   'turning',
#   'radius',
#   'bad',
#   'worst',
#   'existing',
#   '2008',
#   'avenger',
#   'got',
#   'short',
#   'test',
#   'ride',
#   'showroom',
#   'tried',
#   'option',
#   'looking',
#   'new',
#   'change',
#   'upgrading',
#   'existing',
#   '10',
#   'yrs',
#   'old',
#   'also',
#   'got',
#   'test',
#   'ride',
#   'avenger',
#   'cruiser',
#   'okay',
#   'disappointed',
#   'no',
#   'abs',
#   'no',
#   'radial',
#   'tubeless',
#   'tyres',
#   'cruise',
#   'model',
#   'needs',
#   'rethink',
#   'lineup',
#   'existing',
#   'models',
#   'cruise',
#   'no',
#   'abs',
#   'tubeless',
#   'disappointing',
#   'less',
#   'discomfort',
#   'turning',
#   'radius'],
#  ['feel',
#   'bad',
#   'buying',
#   'one',
#   '150',
#   '180',
#   '220cc',
#   'good',
#   'ride',
#   'quality',
#   'materials',
#   'used',
#   'purchased',
#   'one',
#   'big',
#   'mistake',
#   'wear',
#   'tear',
#   'also',
#   'showroom',
#   'treat',
#   'customer',
#   'badly',
#   'thought',
#   'buying',
#   'ninja',
#   '300',
#   'purchased',
#   'big',
#   'mistake',
#   'get',
#   'work',
#   'hardly',
#   'satisfy',
#   'sports',
#   'customers',
#   'not',
#   'showing',
#   'stunt',
#   'advertisements',
#   'giving',
#   'refined',
#   'tension',
#   'free',
#   'engine'],
#  ['muscles',
#   'not',
#   'enough',
#   'others',
#   'already',
#   'explained',
#   'good',
#   'features',
#   'let',
#   'problems',
#   'face',
#   'one',
#   'jump',
#   'dirty',
#   'water',
#   'entire',
#   'space',
#   'tyre',
#   'seat',
#   'gets',
#   'dirty',
#   'bad',
#   'designed',
#   'mudguard',
#   'parked',
#   'weak',
#   'land',
#   'fell',
#   'left',
#   'side',
#   'left',
#   'safety',
#   'bar',
#   'got',
#   'bent',
#   'gear',
#   'clutch',
#   'got',
#   'damaged',
#   'fell',
#   'right',
#   'side',
#   'break',
#   'pedal',
#   'got',
#   'bent',
#   'right',
#   'safety',
#   'bar',
#   'size',
#   'plm',
#   'got',
#   'bent',
#   '45',
#   'degrees',
#   'weak',
#   'cheap',
#   'parts',
#   'heard',
#   'get',
#   'safety',
#   'bars',
#   '750rs',
#   'compare',
#   'shoulder',
#   'wide',
#   'steel',
#   'safety',
#   'bar',
#   'enfield',
#   'designed',
#   'long',
#   'rides',
#   'forget',
#   'large',
#   'baggage',
#   'not',
#   'even',
#   'place',
#   'keep',
#   'carry',
#   'bag',
#   'also',
#   'impossible',
#   'fit',
#   'side',
#   'box',
#   'zero',
#   'space',
#   'back',
#   'seat',
#   'though',
#   'key',
#   'open',
#   'two',
#   'times',
#   'son',
#   'almost',
#   'falling',
#   'sitting',
#   'backside',
#   'not',
#   'know',
#   'designers',
#   'not',
#   'sense',
#   'powered',
#   'least',
#   'inch',
#   'backrest',
#   'else',
#   'not',
#   'provide',
#   'back',
#   'seat'],
#  ['instead',
#   'buying',
#   '400',
#   'buy',
#   'ktm',
#   '250',
#   'worse',
#   'ever',
#   'purchased',
#   'worse',
#   'things',
#   'gets',
#   'vibrate',
#   'lot',
#   'work',
#   'buying',
#   '400cc',
#   'n',
#   'gets',
#   'vibrate',
#   'feels',
#   'like',
#   'riding',
#   '150cc',
#   'request',
#   'u',
#   'think',
#   'n',
#   'invest',
#   'money',
#   '400',
#   'not',
#   'think',
#   'money',
#   'think',
#   'quality'],
#  ['good',
#   'problem',
#   'purchased',
#   '14th',
#   'feb',
#   '2018',
#   'ridden',
#   '700',
#   'km',
#   'whenever',
#   'put',
#   '5th',
#   '6th',
#   'gear',
#   'traffic',
#   'ride',
#   'automatically',
#   'without',
#   'acceleration',
#   'accelerator',
#   'takes',
#   'time',
#   'come',
#   'low',
#   'heating',
#   'problem',
#   'also',
#   'feel',
#   'burning',
#   'sensation',
#   'keeping',
#   'switching',
#   'engine',
#   '3',
#   '4',
#   'hrs',
#   'rest',
#   'good'],
#  ['good',
#   'ride',
#   'amazing',
#   'well',
#   'maintained',
#   'good',
#   'handling',
#   'like',
#   'fascinating',
#   'friends',
#   'love',
#   'much',
#   'pretty',
#   'good',
#   'mileage',
#   'maintenance',
#   'not',
#   'much',
#   'costly',
#   'amazing',
#   'handling',
#   'good',
#   'smooth',
#   'marvellous',
#   'ride',
#   'try',
#   'least'],
#  ['pros',
#   'cons',
#   '1',
#   'went',
#   'buy',
#   'offered',
#   'tea',
#   'high',
#   'price',
#   'negotiate',
#   'well',
#   '2',
#   'riding',
#   'best',
#   'experience',
#   'shock',
#   'absorber',
#   'not',
#   'comfortable',
#   'hero',
#   'cbz',
#   'old',
#   '2015',
#   '16',
#   'model',
#   '3',
#   'look',
#   'wise',
#   'awesome',
#   'performance',
#   'not',
#   'good',
#   'brakes',
#   'good',
#   'torque',
#   'good',
#   'seating',
#   'position',
#   'not',
#   'mark',
#   'back',
#   'seat',
#   'not',
#   'made',
#   'second',
#   'passenger',
#   '4',
#   'servicing',
#   'bad5',
#   'pros',
#   'style',
#   'look',
#   'good',
#   'pickup',
#   'good',
#   'cons',
#   'suspension',
#   'bad',
#   'back',
#   'seat',
#   'bad',
#   'length',
#   'short',
#   'heighted',
#   'person',
#   'looks',
#   'ok',
#   'ok',
#   'not',
#   'good',
#   'forget',
#   'mileage',
#   'tyres',
#   'slippery'],
#  ['satisfied',
#   'not',
#   'bad',
#   'really',
#   'comfortable',
#   'touring',
#   'mileage',
#   'not',
#   'bad',
#   'comfort',
#   'also',
#   'satisfied',
#   'also',
#   'perform',
#   'like',
#   'bull',
#   'cruising',
#   'corner',
#   'top',
#   'speed',
#   'also',
#   'better',
#   'rc',
#   '390',
#   'price',
#   'range',
#   'best',
#   'opinion',
#   'buy',
#   'lover',
#   'touring'],
#  ['awesome',
#   'design',
#   '400',
#   'strong',
#   'machine',
#   'mistake',
#   'means',
#   'vibration',
#   'engine',
#   'not',
#   'comfort',
#   'point',
#   'negative',
#   'price',
#   'tag',
#   'low',
#   'many',
#   'feature',
#   'mileage',
#   'better',
#   'look',
#   'sexy',
#   'performance',
#   'better',
#   'price',
#   'tag',
#   'servicing',
#   'good'],
#  ['400',
#   'buy',
#   'buying',
#   'experience',
#   'nice',
#   '400',
#   'cc',
#   'available',
#   'market',
#   'good',
#   'price',
#   'tag',
#   'riding',
#   'experience',
#   'riding',
#   'experience',
#   '400',
#   'not',
#   'bad',
#   'not',
#   'good',
#   'feel',
#   'abs',
#   'not',
#   'active',
#   'suspension',
#   'could',
#   'better',
#   'improveddetails',
#   'performance',
#   'looks',
#   'performance',
#   'good',
#   'duke',
#   '390',
#   'better',
#   'looks',
#   '400',
#   'great',
#   'could',
#   'better',
#   'company',
#   'could',
#   'given',
#   'engine',
#   'temperature',
#   'meter',
#   'available',
#   'classic',
#   'royal',
#   'enfield',
#   'dukesservicing',
#   'maintenance',
#   'servicing',
#   'maintenance',
#   'much',
#   'easier',
#   'dukes',
#   'quiet',
#   'satisfied',
#   'maintenance',
#   'cost',
#   'pros',
#   'cons',
#   'engine',
#   'temperature',
#   'meter',
#   'missing',
#   'break',
#   'not',
#   'active',
#   'dukes',
#   'good',
#   'looks',
#   'strong',
#   'body',
#   'best',
#   'good',
#   'price',
#   'range',
#   'feel',
#   'value',
#   'money'],
#  ['feel',
#   'performance',
#   'dominor',
#   '400',
#   'monster',
#   'ride',
#   'like',
#   'dominate',
#   'feel',
#   'like',
#   'strong',
#   'fast',
#   'comfort',
#   'fuel',
#   'consumption',
#   'high',
#   'know',
#   '400',
#   'cc',
#   'say',
#   'packet',
#   'hunk',
#   'not',
#   'think',
#   'love',
#   'riding',
#   'go',
#   'buy',
#   'go',
#   'long',
#   'ride',
#   'make',
#   'journey'],
#  ['decent',
#   'could',
#   'much',
#   'better',
#   'buying',
#   'experience',
#   'not',
#   'good',
#   'told',
#   'booking',
#   'would',
#   'get',
#   '10',
#   'days',
#   'almost',
#   'took',
#   'month',
#   'arrive',
#   'plus',
#   'tried',
#   'sell',
#   'lying',
#   'around',
#   'showroom',
#   'day',
#   'booked',
#   'wait',
#   'highways',
#   'find',
#   'powerful',
#   'well',
#   'comfortable',
#   'no',
#   'complaints',
#   'city',
#   'traffic',
#   'no',
#   'fun',
#   'much',
#   'engine',
#   'braking',
#   'results',
#   'frequent',
#   'shifting',
#   'release',
#   'throttle',
#   'huge',
#   'drag',
#   'forces',
#   'shift',
#   'not',
#   'roll',
#   'not',
#   'faced',
#   'heating',
#   'issues',
#   'though',
#   'although',
#   'vibrations',
#   'cross',
#   '4k',
#   'rpm',
#   'annoying',
#   'actually',
#   'vibrations',
#   'noise',
#   'caused',
#   'vibrations',
#   'annoys',
#   'also',
#   'facing',
#   'power',
#   'lag',
#   'issues',
#   'not',
#   'know',
#   'ecu',
#   'fi',
#   'problem',
#   'service',
#   'centre',
#   'not',
#   'find',
#   'resolution',
#   'hence',
#   'actually',
#   'say',
#   'no',
#   'issue',
#   'not',
#   'even',
#   'guts',
#   'say',
#   'not',
#   'solution',
#   'pissed',
#   'looks',
#   'awesome',
#   'no',
#   'doubt',
#   'one',
#   'major',
#   'reasons',
#   'bought',
#   'points',
#   'favour',
#   'price',
#   'point',
#   'abs',
#   'not',
#   'faced',
#   'major',
#   'expenses',
#   'maintenance',
#   'till',
#   'regular',
#   'servicing',
#   'costs',
#   'around',
#   '1500',
#   'paid',
#   'servicing',
#   'yet',
#   'start',
#   'getting',
#   'mileage',
#   'around',
#   '26',
#   '27',
#   'city',
#   'summarise',
#   'not',
#   'happy',
#   'would',
#   'not',
#   'recommend',
#   'anyone',
#   'pros',
#   '1',
#   'stunning',
#   'looks',
#   '2',
#   'good',
#   'performance',
#   'highways',
#   '3',
#   'good',
#   'pricing',
#   'cons',
#   '1',
#   'much',
#   'engine',
#   'braking',
#   'driving',
#   'city',
#   'traffic',
#   'pain',
#   '2',
#   'lot',
#   'vibrations',
#   'near',
#   'tank',
#   '4k',
#   'rpm',
#   '3',
#   'power',
#   'lag',
#   'issues'],
#  ['honest',
#   'review',
#   'dominor',
#   '400',
#   'look',
#   'good',
#   'many',
#   'quality',
#   'issues',
#   'started',
#   'kms',
#   'crossed',
#   'e',
#   'g',
#   '2000',
#   'km',
#   'disk',
#   'scratches',
#   'vibrating',
#   'plastics',
#   'service',
#   'not',
#   'tomark',
#   'not',
#   'experienced',
#   'service',
#   'technicians',
#   'apart',
#   'satisfy',
#   'yourneed',
#   'not',
#   'expect',
#   'mileage',
#   '20km',
#   'throttle',
#   'power',
#   'not',
#   'expect',
#   'till',
#   'first',
#   'service',
#   'completion',
#   'abs',
#   'working',
#   'good'],
#  ['not',
#   'worthy',
#   '2',
#   'lakhs',
#   'cons',
#   '1',
#   'may',
#   'reviews',
#   'mentioned',
#   'good',
#   'go',
#   'long',
#   'ride',
#   '150km',
#   'focus',
#   'fuel',
#   'level',
#   'display',
#   'wont',
#   'update',
#   'properly',
#   'update',
#   'correct',
#   'bars',
#   'key',
#   'key',
#   'else',
#   'wont',
#   'update',
#   'faced',
#   'issue',
#   '2',
#   'times',
#   'going',
#   'fast',
#   'apply',
#   'back',
#   'brake',
#   'small',
#   'stuck',
#   'sound',
#   'may',
#   'not',
#   'bikes',
#   'pro',
#   'never',
#   'feel',
#   'back',
#   'pain',
#   'handle',
#   'dual',
#   'abs',
#   'advantage',
#   'no',
#   'proper',
#   'technicians',
#   'service',
#   'center',
#   'market',
#   'could',
#   'better',
#   'add',
#   'gear',
#   'number',
#   'display',
#   'horn',
#   'sound',
#   'irritating'],
#  ['layman',
#   'review',
#   'going',
#   'depth',
#   'would',
#   'like',
#   'impart',
#   'points',
#   'people',
#   'position',
#   'similar',
#   'get',
#   'best',
#   'review',
#   'common',
#   'man',
#   'not',
#   'geek',
#   'like',
#   'get',
#   'depth',
#   'thrust',
#   'power',
#   'etc',
#   'use',
#   'day',
#   'day',
#   'city',
#   'rides',
#   'twice',
#   'month',
#   'long',
#   'rides',
#   'around',
#   '450',
#   'km',
#   'height',
#   'around',
#   '171',
#   'cm',
#   'weight',
#   '70',
#   'kg',
#   'important',
#   'handle',
#   '180',
#   'kilos',
#   'machine',
#   '1',
#   'buying',
#   'experience',
#   'showroom',
#   'people',
#   'friendly',
#   'gave',
#   'test',
#   'ride',
#   'explained',
#   'features',
#   'however',
#   'first',
#   'set',
#   'since',
#   'new',
#   'launch',
#   'not',
#   'aware',
#   'minute',
#   'details',
#   '2',
#   'riding',
#   'ownership',
#   'experience',
#   'going',
#   'depth',
#   'would',
#   'like',
#   'impart',
#   'points',
#   'people',
#   'position',
#   'similar',
#   'get',
#   'best',
#   'review',
#   'common',
#   'man',
#   'not',
#   'geek',
#   'like',
#   'get',
#   'depth',
#   'thrust',
#   'power',
#   'etc',
#   'use',
#   'day',
#   'day',
#   'city',
#   'rides',
#   'twice',
#   'month',
#   'long',
#   'rides',
#   'around',
#   '450',
#   'km',
#   'height',
#   'around',
#   '171',
#   'cm',
#   'weight',
#   '70',
#   'kg',
#   'important',
#   'handle',
#   '180',
#   'kilos',
#   'machine',
#   'lets',
#   'get',
#   'straight',
#   'review',
#   'two',
#   'categories',
#   'negative',
#   'positive',
#   'negatives',
#   'like',
#   'said',
#   'layman',
#   'even',
#   'know',
#   'bikes',
#   'middle',
#   'stand',
#   'kick',
#   'rod',
#   'start',
#   'careful',
#   'reviews',
#   'decided',
#   'buy',
#   'realised',
#   'showroom',
#   'missing',
#   'however',
#   'went',
#   'ahead',
#   'bought',
#   'due',
#   'super',
#   'positive',
#   'reviews',
#   'mention',
#   'because1',
#   'design',
#   'quality',
#   'side',
#   'stand',
#   'provided',
#   'ultra',
#   'poor',
#   'times',
#   'doubt',
#   'may',
#   'collapse',
#   'poor',
#   'design',
#   'even',
#   '120',
#   'kilos',
#   'platina',
#   'diameter',
#   'stand',
#   'quality',
#   'poor',
#   'started',
#   'getting',
#   'rust',
#   'immediately',
#   'three',
#   'months',
#   '2',
#   'received',
#   'broken',
#   'battery',
#   'new',
#   'one',
#   'fine',
#   'day',
#   'tried',
#   'start',
#   'immediately',
#   'called',
#   'service',
#   'centre',
#   'verified',
#   'confirmed',
#   'battery',
#   'broken',
#   'go',
#   'mentioned',
#   'responsible',
#   'battery',
#   'tyres',
#   'according',
#   'nature',
#   'fought',
#   'battery',
#   'broken',
#   'run',
#   'hardly',
#   '500',
#   'km',
#   'finally',
#   'convinced',
#   'mentioned',
#   'replaced',
#   'takes',
#   'minimum',
#   '21',
#   'days',
#   'managed',
#   'push',
#   'delivery',
#   'five',
#   'days',
#   '3',
#   'started',
#   'getting',
#   'strange',
#   'chain',
#   'noise',
#   'week',
#   'sale',
#   'enquired',
#   'service',
#   'centre',
#   'mentioned',
#   'chain',
#   'lubricant',
#   'must',
#   'applied',
#   'every',
#   '500',
#   'km',
#   'told',
#   'even',
#   'rode',
#   '200',
#   'km',
#   'come',
#   'noise',
#   'coming',
#   'finally',
#   'understood',
#   'design',
#   'flaw',
#   'must',
#   'apply',
#   'chain',
#   'lubricant',
#   'every',
#   '150',
#   'km',
#   'going',
#   'ride',
#   '150',
#   'km',
#   'keep',
#   'bottle',
#   'chain',
#   'lubricant',
#   'bag',
#   'points',
#   'till',
#   'first',
#   'service',
#   'experience',
#   '3rd',
#   'month',
#   'ownership',
#   'one',
#   'fine',
#   'day',
#   'found',
#   'pool',
#   'oil',
#   'around',
#   'called',
#   'service',
#   'centre',
#   'immediately',
#   'appeared',
#   'confirmed',
#   'back',
#   'shock',
#   'absorber',
#   'damaged',
#   'manufacturing',
#   'defect',
#   'however',
#   'ride',
#   'till',
#   'get',
#   'replacement',
#   'company',
#   'may',
#   'take',
#   'another',
#   '21',
#   'days',
#   'careful',
#   'driving',
#   'limit',
#   'speed',
#   '50',
#   'kmph',
#   'got',
#   'replacement',
#   '21',
#   'days',
#   'along',
#   'back',
#   'pain',
#   'no',
#   'hook',
#   'facility',
#   'hang',
#   'bags',
#   'put',
#   'one',
#   'well',
#   'no',
#   'options',
#   'must',
#   'carry',
#   'helmet',
#   'wherever',
#   'go',
#   'no',
#   'shopping',
#   'back',
#   'pack',
#   'another',
#   'flaw',
#   'handling',
#   'important',
#   'valid',
#   'point',
#   'hard',
#   'handle',
#   'normal',
#   'city',
#   'traffics',
#   'curves',
#   'trust',
#   'i20',
#   'turning',
#   'radius',
#   'far',
#   'better',
#   'would',
#   'fallen',
#   'badly',
#   'kid',
#   'not',
#   'extra',
#   'careful',
#   'aware',
#   'handling',
#   'beast',
#   'disaster',
#   'trust',
#   'something',
#   'terribly',
#   'wrong',
#   'gear',
#   'ration',
#   'even',
#   'riding',
#   '4000',
#   'km',
#   'not',
#   'able',
#   'understand',
#   'work',
#   'get',
#   'stops',
#   'often',
#   'slow',
#   'speeds',
#   'found',
#   'fuel',
#   'issue',
#   'speed',
#   '50',
#   'km',
#   'accelerator',
#   'not',
#   'working',
#   'positives',
#   'speed',
#   'speed',
#   'speed',
#   'rode',
#   '140',
#   'kmph',
#   'no',
#   'vibrations',
#   'excellent',
#   'pickup',
#   'great',
#   'speed',
#   'even',
#   'speed',
#   'feel',
#   'confident',
#   'brakes',
#   'abs',
#   'version',
#   'stand',
#   'idle',
#   'wheels',
#   'whenever',
#   'want',
#   'brakes',
#   'work',
#   'like',
#   'heaven',
#   'best',
#   'control',
#   'speed',
#   'head',
#   'light',
#   'see',
#   'much',
#   'advantage',
#   'feel',
#   'difference',
#   'better',
#   'led',
#   'struggling',
#   'yellow',
#   'lamp',
#   'lights'],
#  ['ownership',
#   'review',
#   '1',
#   'year',
#   '50',
#   '70',
#   'kms',
#   'daily',
#   'commute',
#   'bought',
#   'october',
#   '2017',
#   'first',
#   'generation',
#   'excited',
#   'still',
#   'considering',
#   'price',
#   'course',
#   'value',
#   'money',
#   'proposition',
#   'ride',
#   'paint',
#   'quality',
#   'could',
#   'better',
#   'year',
#   'faced',
#   'issues',
#   'cons',
#   '1',
#   'suspensions',
#   'hard',
#   'indian',
#   'roads',
#   'roads',
#   'delhi',
#   'good',
#   'unexpected',
#   'pothole',
#   'sufficient',
#   'shock',
#   'kidneys',
#   '2',
#   'power',
#   'lag',
#   'despite',
#   'using',
#   'recommended',
#   'procedures',
#   'switch',
#   'motul',
#   'engine',
#   'oil',
#   'made',
#   'slight',
#   'decrease',
#   'engine',
#   'buzz',
#   'onto',
#   'handle',
#   'bars',
#   'sometimes',
#   'feels',
#   'like',
#   '2',
#   '3k',
#   'capacity',
#   'motorcycle',
#   'not',
#   'know',
#   'r15',
#   'guy',
#   'manage',
#   'pull',
#   'faster',
#   'signals',
#   'despite',
#   'using',
#   'accelerator',
#   'fullest',
#   '3',
#   'chain',
#   'lubrication',
#   'required',
#   'frequently',
#   'else',
#   'start',
#   'feeling',
#   'difference',
#   'within',
#   '300',
#   'kms',
#   '4',
#   'gear',
#   'thud',
#   'annoying',
#   'pros',
#   '1',
#   'value',
#   'money',
#   '400',
#   'cc2',
#   'build',
#   'quality',
#   'solid',
#   'never',
#   'experienced',
#   'loose',
#   'parts',
#   'despite',
#   'plastic',
#   'heavily',
#   'utilized',
#   '3',
#   'feature',
#   'packed'],
#  ['engine',
#   'heat',
#   'buyed',
#   'new',
#   '400',
#   '2019',
#   'variant',
#   'would',
#   'like',
#   'share',
#   'views',
#   'riding',
#   'experience',
#   'performance',
#   'no',
#   'doubt',
#   'excellent',
#   'one',
#   'heating',
#   'engine',
#   'serious',
#   'concern',
#   'bought',
#   '9',
#   'days',
#   'ago',
#   'today',
#   'started',
#   'home',
#   'office',
#   'engine',
#   'caught',
#   'fire',
#   'wired',
#   'cables',
#   'got',
#   'burnt',
#   'smoke',
#   'heat',
#   'coming',
#   'hardly',
#   'travelled',
#   '5',
#   'kms',
#   'engine',
#   'got',
#   'heated',
#   'caught',
#   'fire',
#   'though',
#   'standing',
#   'whole',
#   'night',
#   'no',
#   'chance',
#   'engine',
#   'warm',
#   'hand',
#   'bad',
#   'riding',
#   'experience',
#   'not',
#   'expected',
#   'brand',
#   'new',
#   'finally',
#   'called',
#   'tow',
#   'truck',
#   'take',
#   'workshop'],
#  ['amazing',
#   'ride',
#   'quality',
#   'riding',
#   'experience',
#   'sublime',
#   'ruins',
#   'way',
#   'indian',
#   'feel',
#   'like',
#   'drag',
#   'need',
#   'feel',
#   'power',
#   'travelled',
#   'constant',
#   'speed',
#   '120',
#   'hour',
#   'ride',
#   'smooth',
#   'power',
#   'like',
#   'sports',
#   'also',
#   'cruise',
#   'becomes',
#   'wonderful',
#   'people',
#   'tall',
#   'would',
#   'not',
#   'really',
#   'recommend',
#   'buy',
#   'less',
#   '5',
#   '8',
#   'height'],
#  ['beast',
#   'intense',
#   'roar',
#   'amazing',
#   'time',
#   'riding',
#   'sports',
#   'cruiser',
#   'best',
#   'thing',
#   'sound',
#   'stock',
#   'exhaust',
#   'superb',
#   'experience',
#   'whole',
#   'another',
#   'appealing',
#   'thing',
#   'head',
#   'mask',
#   'tail',
#   'light',
#   'led',
#   'placement',
#   'front',
#   'light',
#   'gives',
#   'beast',
#   'look',
#   'meter',
#   'tank',
#   'gives',
#   'elegant',
#   'look'],
#  ['complete',
#   'package',
#   'awesome',
#   'looking',
#   'new',
#   'model',
#   'best',
#   'daily',
#   'commute',
#   'new',
#   'mirrors',
#   'attention',
#   'seeking',
#   'rims',
#   'good',
#   'compared',
#   'golden',
#   'color',
#   'combination',
#   'also',
#   'good',
#   'power',
#   'improved',
#   'much',
#   'complete',
#   'package',
#   'affordable',
#   'price',
#   'classic',
#   '350',
#   'thinking',
#   'forward',
#   'sson'],
#  ['unbelievable',
#   'performance',
#   'good',
#   'performance',
#   'also',
#   'good',
#   'mileage',
#   'less',
#   '20',
#   'look',
#   'awesome',
#   'cheaper',
#   'comparing',
#   'vehicle',
#   'like',
#   'ktm',
#   'yamaha',
#   'suzuki',
#   'royal',
#   'enfield',
#   'better',
#   'abs',
#   'advance',
#   'braking',
#   'system',
#   'less',
#   'chance',
#   'feel',
#   'not',
#   'superbike'],
#  ['devil',
#   'sit',
#   'feel',
#   'command',
#   'roads',
#   'nimble',
#   'easy',
#   'manoeuvre',
#   'provides',
#   'great',
#   'front',
#   'end',
#   'feel',
#   'ride',
#   'refined',
#   'engine',
#   'gets',
#   '4500',
#   'kms',
#   'smooth',
#   'butter',
#   'believe',
#   '35',
#   'horses',
#   'combined',
#   '35',
#   'nm',
#   'torque',
#   'enough',
#   'never',
#   'let',
#   'get',
#   'bored',
#   'overtaking',
#   'fun',
#   'thrilling',
#   'brakes',
#   'reassuring',
#   'price',
#   'find',
#   'anything',
#   'better',
#   'market',
#   'night',
#   'dark',
#   'matte',
#   'black',
#   'lets',
#   'believe',
#   'batman',
#   'put',
#   'cape',
#   'ride',
#   'darkness'],
#  ['tour',
#   'awesome',
#   'touring',
#   'tour',
#   'pune',
#   'maharashtra',
#   'assam',
#   'guwahati',
#   'total',
#   'distance',
#   '2700',
#   'km',
#   'completed',
#   '5',
#   'days',
#   'comfortable',
#   'fuel',
#   'efficiency',
#   'good',
#   'sitting',
#   'position',
#   'good',
#   'riding',
#   'experience',
#   'excellent',
#   'good',
#   'looking',
#   'like',
#   'king',
#   'low',
#   'cost',
#   'maintenance',
#   'reliability',
#   'good',
#   '5',
#   '4'],
#  ['stunning',
#   'new',
#   '6',
#   'month',
#   'old',
#   'pretty',
#   'awesome',
#   'abs',
#   'works',
#   'like',
#   'charm',
#   'slipper',
#   'clutch',
#   'added',
#   'benefits',
#   'makes',
#   'ride',
#   'smooth',
#   'best',
#   'sports',
#   'cruiser',
#   'city',
#   'mid',
#   'range',
#   'power',
#   'help',
#   'sail',
#   'traffic',
#   'easily',
#   'double',
#   'seat',
#   'never',
#   'problem',
#   'not',
#   'affect',
#   'power',
#   'makes',
#   'awesome',
#   'sound',
#   'especially',
#   'rev',
#   'mid',
#   'range'],
#  ['new',
#   'diamond',
#   'cut',
#   'alloy',
#   'wheels',
#   '400',
#   'pretty',
#   'good',
#   'look',
#   'well',
#   '400',
#   'cc',
#   'powerful',
#   'engine',
#   'air',
#   'cooled',
#   'system',
#   'technology',
#   'new',
#   'green',
#   'black',
#   'colour',
#   'diamond',
#   'cut',
#   'alloy',
#   'wheels',
#   'purpose',
#   'excellent',
#   'grip',
#   'highways',
#   'love',
#   'ghat',
#   'sections',
#   'led',
#   'headlight',
#   'head',
#   'turner',
#   'maintenance',
#   'cost',
#   'economical'],
#  ['rider',
#   '10',
#   'done',
#   'wonderful',
#   'job',
#   'looks',
#   'naked',
#   '400',
#   'buying',
#   'experience',
#   'good',
#   'service',
#   'staff',
#   'helpful',
#   'gave',
#   'every',
#   'needed',
#   'information',
#   'wanted',
#   'also',
#   'even',
#   'not',
#   'knew',
#   'almost',
#   'done',
#   '12000km',
#   'still',
#   'no',
#   'mood',
#   'discontinue',
#   'riding',
#   'smooth',
#   'almost',
#   'forget',
#   'issues',
#   'con',
#   'way',
#   'would',
#   'give',
#   '4',
#   '5',
#   'looks',
#   'performance',
#   'really',
#   'good',
#   'really',
#   'count',
#   'really',
#   'need',
#   'buddy',
#   'indian',
#   'obviously',
#   'india',
#   'spare',
#   'parts',
#   'easily',
#   'available',
#   'not',
#   'expensive',
#   'service',
#   'cost',
#   'also',
#   'not',
#   'high',
#   'ktm',
#   'bikes',
#   'yeah',
#   'find',
#   'good',
#   'mechanic',
#   'many',
#   'mechanics',
#   'not',
#   'knew',
#   'many',
#   'things',
#   'unique',
#   'dual',
#   'channel',
#   'abs',
#   'provides',
#   'safe',
#   'ride',
#   'feels',
#   'grippy',
#   'roads',
#   'also',
#   'heating',
#   'issues',
#   'not',
#   'felt',
#   'liquid',
#   'cooled',
#   'engine',
#   'hardly',
#   'feel',
#   'radiator',
#   'vibrations',
#   'kind',
#   'issue',
#   'according',
#   'not',
#   'problem',
#   'bit',
#   'vibrations'],
#  ['rounder',
#   'value',
#   'money',
#   'simply',
#   'great',
#   'unbeatable',
#   'value',
#   'money',
#   '1',
#   'awesome',
#   'purchase',
#   'terrific',
#   'value',
#   'money',
#   'latest',
#   'features',
#   'specifications',
#   '2',
#   'riding',
#   'experience',
#   'amazing',
#   'riding',
#   'position',
#   'perfect',
#   'long',
#   'rides',
#   'seat',
#   'little',
#   'hard',
#   '3',
#   'looks',
#   'performance',
#   'excellent',
#   '4',
#   'servicing',
#   'maintenance',
#   'easy',
#   'wallets',
#   '5',
#   'pros',
#   'looks',
#   'performance',
#   'specs',
#   'riding',
#   'experience',
#   'value',
#   'money',
#   'cons',
#   'hard',
#   'seat',
#   'n',
#   'little',
#   'vibes'],
#  ['hyper',
#   'review',
#   'nice',
#   'powerful',
#   'engine',
#   'performance',
#   'good',
#   'excellent',
#   '2',
#   'lakhs',
#   'compare',
#   'apache',
#   '310',
#   'better',
#   'gives',
#   'nice',
#   'punch',
#   'pull',
#   'throttle',
#   'given',
#   'blind',
#   'opposite',
#   'rider',
#   'high',
#   'beam',
#   'fix',
#   'vibration',
#   'issue',
#   'pros',
#   'performance',
#   'light',
#   'build',
#   'quality',
#   'cons',
#   'vibration'],
#  ['good',
#   'nice',
#   '2',
#   'lakh',
#   'main',
#   'point',
#   '400',
#   'superior',
#   'bikes',
#   'see',
#   'companies',
#   'like',
#   'kawasaki',
#   'brands',
#   'providing',
#   'different',
#   'issues',
#   'different',
#   'qualities',
#   'compromising',
#   'similarities',
#   'mean',
#   'awesome',
#   'mileage',
#   'consumption',
#   'poor',
#   'not',
#   'problem'],
#  ['charge',
#   'road',
#   '400',
#   'got',
#   '400',
#   '22nd',
#   'birthday',
#   'abj',
#   'godda',
#   'reason',
#   'best',
#   '1',
#   '7',
#   'lac',
#   '373',
#   '3cc',
#   'single',
#   'cylinder',
#   'fi',
#   'engine',
#   'produces',
#   '34',
#   '5',
#   'hp',
#   'power',
#   '35',
#   'nm',
#   'torque',
#   'engine',
#   'comes',
#   '6',
#   'speed',
#   'gearbox',
#   '400',
#   'offered',
#   'dual',
#   'channel',
#   'abs',
#   '400',
#   'great',
#   'sporty',
#   'looks',
#   'following',
#   'features',
#   '400',
#   'mileage',
#   'mileage',
#   '26',
#   '30',
#   'km',
#   'ltop',
#   'speed',
#   '148',
#   'km',
#   'hr',
#   'engine',
#   'cc',
#   '373',
#   '3cc',
#   'single',
#   'cylinder',
#   '2',
#   '400',
#   'specifications',
#   'dimension',
#   'length',
#   'mm',
#   '2156width',
#   'mm',
#   '813',
#   'height',
#   'mm',
#   '1112',
#   'wheelbase',
#   'mm',
#   'distance',
#   'middle',
#   'front',
#   'rear',
#   'wheel',
#   '1453',
#   'ground',
#   'clearance',
#   'mm',
#   'height',
#   'vehicle',
#   'body',
#   'ground',
#   '157',
#   'height',
#   'seat',
#   'mm',
#   'na',
#   'kerb',
#   'weight',
#   'kgs',
#   '182',
#   'kgs',
#   'pros',
#   '1',
#   'excellent',
#   'grip',
#   'highways',
#   '2',
#   'braking',
#   'system',
#   'plus',
#   'point',
#   '3',
#   'ride',
#   '143kmph',
#   'not',
#   'shiver',
#   '4',
#   'liquid',
#   'cooled',
#   'engine',
#   'long',
#   'tours',
#   '5',
#   'headlamps',
#   'powerful',
#   'throw',
#   'light',
#   '1',
#   '5km',
#   'straight',
#   'road',
#   '6',
#   'strong',
#   'built',
#   '7',
#   'gears',
#   'smooth',
#   'cons',
#   '1',
#   'engine',
#   'gets',
#   'heated',
#   'city',
#   'roads',
#   '2',
#   'city',
#   'ride',
#   'pain',
#   'ass',
#   '3',
#   'rear',
#   'seat',
#   'issue',
#   'bumpy',
#   '4',
#   'mileage',
#   'less',
#   'compared',
#   'rivals',
#   'overall',
#   'good',
#   'love',
#   'cruising',
#   'around',
#   'highways',
#   'ride',
#   '600kms',
#   'week',
#   'issue',
#   'city',
#   'ride',
#   'mileage',
#   'would',
#   'give',
#   '4',
#   'stars'],
#  ['value',
#   'mine',
#   '1',
#   'buying',
#   'experience',
#   'ans',
#   'purchased',
#   'kalyani',
#   'yelahanka',
#   'bangalore',
#   'karnataka',
#   'put',
#   'staff',
#   'untrained',
#   'incapable',
#   'explaining',
#   'single',
#   'point',
#   'struggling',
#   '15',
#   'min',
#   'gave',
#   'product',
#   'catalog',
#   'told',
#   'please',
#   'go',
#   'find',
#   'answer',
#   'next',
#   'shock',
#   'booked',
#   'paying',
#   '5000',
#   'told',
#   'please',
#   'come',
#   'tomorrow',
#   'pay',
#   'full',
#   'amount',
#   'take',
#   'front',
#   'everybody',
#   'imps',
#   'remaining',
#   'amount',
#   'took',
#   '45',
#   'min',
#   'confirm',
#   'amount',
#   'credited',
#   'take',
#   '2',
#   'riding',
#   'experience',
#   'answer',
#   'various',
#   'factors',
#   'responsible',
#   'comfortable',
#   'riding',
#   'point',
#   'riding',
#   'posture',
#   'looking',
#   'see',
#   'meant',
#   'touring',
#   'commuting',
#   'since',
#   'high',
#   'power',
#   'people',
#   'prefer',
#   'commute',
#   'mileage',
#   'factor',
#   'b',
#   '373',
#   'cc',
#   'liquid',
#   'cooled',
#   'engine',
#   'gives',
#   'good',
#   'power',
#   'abs',
#   'give',
#   'good',
#   'control',
#   'power',
#   'c',
#   'looks',
#   'stunning',
#   'great',
#   'led',
#   'headlamps',
#   'led',
#   'indicators',
#   'sharp',
#   'detailing',
#   'paint',
#   'job',
#   'performance',
#   'not',
#   'adding',
#   'specifications',
#   'already',
#   'bikewale',
#   'com',
#   'getting',
#   '373',
#   'cc',
#   'engine',
#   'borrowed',
#   'ktm',
#   'gives',
#   'stunning',
#   'pickup',
#   'well',
#   'torque',
#   'service',
#   'maintenance',
#   'service',
#   'cost',
#   'lower',
#   'category',
#   'service',
#   'period',
#   'whooping',
#   '5k',
#   'km',
#   'care',
#   'full',
#   'engine',
#   'oil',
#   'topup',
#   'ans',
#   'chain',
#   'lubing',
#   'paid',
#   'service',
#   'generally',
#   'cost',
#   'around',
#   '25k',
#   '3k',
#   'minor',
#   'part',
#   'change',
#   'pros',
#   'value',
#   'money',
#   'every',
#   'bit',
#   'build',
#   'indian',
#   'road',
#   'literally',
#   'take',
#   'anywhere',
#   'long',
#   'tour',
#   'including',
#   'adventures',
#   'large',
#   'wheel',
#   'base',
#   'ans',
#   'disk',
#   'effective',
#   'braking',
#   'dual',
#   'instrument',
#   'cluster',
#   'cons',
#   'no',
#   'abs',
#   'switch',
#   'no',
#   'fuel',
#   'tap',
#   'ab',
#   'bit',
#   'heavy',
#   '182',
#   'kgs'],
#  ['good',
#   'touring',
#   'love',
#   '400',
#   'good',
#   'touring',
#   '400cc',
#   'segment',
#   'value',
#   'money',
#   'feel',
#   'good',
#   'satisfaction',
#   'short',
#   'boy',
#   'easily',
#   'control',
#   '400',
#   'suitable',
#   'body',
#   'language',
#   'buy',
#   'form',
#   'good',
#   'showroom',
#   'get',
#   'best',
#   'offers'],
#  ['beast',
#   'road',
#   'dominate',
#   'others',
#   'bikes',
#   'traveled',
#   '14000',
#   'kms',
#   '5',
#   'months',
#   'whole',
#   'experience',
#   'city',
#   'highways',
#   'roads',
#   'ghat',
#   'roads',
#   'never',
#   'feel',
#   'kind',
#   'difficulty',
#   'things',
#   'service',
#   'centers',
#   'hyderabad',
#   'service',
#   'center',
#   'engineers',
#   'not',
#   'trained',
#   'service',
#   'maintenance',
#   'cost',
#   'till',
#   'zero'],
#  ['actual',
#   'performance',
#   'motorcycle',
#   'india',
#   'deserves',
#   'great',
#   'motorcycle',
#   'stable',
#   'go',
#   'boasting',
#   'looks',
#   'performance',
#   'comfort',
#   'etc',
#   'importantly',
#   'given',
#   'us',
#   'vfm',
#   'product',
#   'crunch',
#   'miles',
#   'like',
#   'morning',
#   'breakfast',
#   'well',
#   'tidy',
#   'city',
#   'commutes',
#   'starting',
#   'appearance',
#   'looker',
#   'everyone',
#   'surely',
#   'give',
#   'glance',
#   'even',
#   'small',
#   'one',
#   'front',
#   'approach',
#   'big',
#   'fang',
#   'like',
#   'led',
#   'drls',
#   'amazing',
#   'task',
#   'efficiently',
#   'side',
#   'profile',
#   'big',
#   'got',
#   'superbike',
#   'esque',
#   'feeling',
#   'even',
#   'one',
#   'astride',
#   'performance',
#   'amazing',
#   'though',
#   'not',
#   'like',
#   'duke',
#   '390',
#   'tad',
#   'less',
#   'due',
#   'sheer',
#   'weight',
#   'torque',
#   'quite',
#   'punchy',
#   'picks',
#   'revs',
#   'quickly',
#   'no',
#   'time',
#   'one',
#   'might',
#   'triple',
#   'digits',
#   'gearbox',
#   'fine',
#   'shifting',
#   '1st',
#   'n',
#   'makes',
#   'loud',
#   'inevitable',
#   'clunk',
#   'sound',
#   'breeze',
#   'due',
#   'weight',
#   'straight',
#   'line',
#   'stability',
#   'brilliant',
#   'fuel',
#   'efficiency',
#   'takes',
#   'hit',
#   'giving',
#   'around',
#   '32',
#   'highways',
#   '27',
#   'cities',
#   'ridden',
#   'sedately',
#   'exhaust',
#   'note',
#   'got',
#   'throaty',
#   'pinch',
#   'riding',
#   'position',
#   'relaxed',
#   'raised',
#   'handlebars',
#   'slight',
#   'rear',
#   'set',
#   'foot',
#   'pegs',
#   'one',
#   'go',
#   'long',
#   'trips',
#   'without',
#   'hassles',
#   'pillion',
#   'comfort',
#   'also',
#   'good',
#   'not',
#   'best',
#   'cornering',
#   'not',
#   'problem',
#   'considering',
#   'weight',
#   'motorcycle',
#   'geometry',
#   'not',
#   'meant',
#   'sports',
#   'cruiser',
#   'sweet',
#   'spot',
#   '120',
#   '25',
#   'though',
#   '150',
#   'features',
#   'wise',
#   'loaded',
#   'full',
#   'digital',
#   'console',
#   'dual',
#   'dual',
#   'channel',
#   'abs',
#   'slipper',
#   'clutch',
#   'beautiful',
#   'led',
#   'headlamps',
#   'usp',
#   'liquid',
#   'cooling',
#   'fuel',
#   'injection',
#   'etc',
#   '1',
#   '9',
#   'lakhs',
#   'road',
#   'guwahati',
#   'parts',
#   'cheap',
#   'normal',
#   'servicing',
#   'would',
#   'cost',
#   '1',
#   '5k',
#   'negative',
#   'side',
#   'not',
#   'many',
#   'important',
#   'ones',
#   'like',
#   'clunky',
#   '1st',
#   'gear',
#   'weird',
#   'crashing',
#   'sounds',
#   'heard',
#   'towards',
#   'rear',
#   'end',
#   'motorcycle',
#   'riding',
#   'potholes',
#   'bad',
#   'patches',
#   'roads',
#   'might',
#   'thing',
#   'overall',
#   'vfm',
#   'sports',
#   'cruiser',
#   'given',
#   'meant',
#   'rule',
#   'highways',
#   'subtracting',
#   'quality',
#   'niggles',
#   'buy',
#   'one',
#   'yes',
#   'definitely'],
#  ['perfect',
#   'touring',
#   'machine',
#   '1',
#   'buying',
#   'experience',
#   'decided',
#   'buy',
#   'blue',
#   '2018',
#   'version',
#   'late',
#   '2017',
#   'booked',
#   'vehicle',
#   '15th',
#   'january',
#   '2018',
#   'wait',
#   'month',
#   'get',
#   'color',
#   'asked',
#   'showroom',
#   'guys',
#   'not',
#   'helpful',
#   'call',
#   'check',
#   'delivery',
#   'status',
#   'keep',
#   'repeating',
#   'not',
#   'production',
#   'sent',
#   'complaint',
#   'mail',
#   'regional',
#   'head',
#   'got',
#   'call',
#   'showroom',
#   'arranged',
#   'mid',
#   'february',
#   'finally',
#   'received',
#   'dad',
#   'took',
#   'showroom',
#   'not',
#   'available',
#   'town',
#   'wow',
#   'love',
#   'color',
#   'muscles',
#   'buying',
#   'experience',
#   'not',
#   'fruitful',
#   'worst',
#   '2',
#   'riding',
#   'experience',
#   'test',
#   'drive',
#   'totally',
#   'love',
#   'beast',
#   'riding',
#   'quality',
#   'awesome',
#   'hit',
#   '3',
#   'digit',
#   'speeds',
#   'fewer',
#   'seconds',
#   'small',
#   'vibrations',
#   'cross',
#   '6000',
#   'rpm',
#   'seat',
#   'comfortable',
#   'rider',
#   'pillion',
#   'seating',
#   'could',
#   'done',
#   'better',
#   'not',
#   'comfortable',
#   'long',
#   'rides',
#   'year',
#   'always',
#   'amazed',
#   'ignite',
#   'ride',
#   'brakes',
#   'powerful',
#   'rely',
#   'overall',
#   'riding',
#   'quality',
#   'fantastic',
#   '3',
#   'details',
#   'looks',
#   'performance',
#   'etc',
#   'absolute',
#   'beauty',
#   'muscles',
#   'led',
#   'headlamp',
#   'best',
#   'class',
#   'looks',
#   'somewhat',
#   'similar',
#   'pulsar',
#   'ns',
#   'golden',
#   'alloy',
#   'combination',
#   'coolest',
#   'performance',
#   'wise',
#   'value',
#   'money',
#   'ride',
#   'hours',
#   'without',
#   'breaking',
#   'sweat',
#   'abs',
#   'slipper',
#   'clutch',
#   'added',
#   'advantages',
#   'fuel',
#   'tank',
#   'capacity',
#   '13',
#   'l',
#   'small',
#   'quantity',
#   'big',
#   'beast',
#   'mileage',
#   'ok',
#   'city',
#   'getting',
#   '25',
#   '27',
#   'km',
#   'pl',
#   'highway',
#   'rides',
#   'get',
#   '31',
#   '34',
#   'km',
#   'pl',
#   'usually',
#   'fill',
#   'tank',
#   'ride',
#   '300',
#   'km',
#   'refill',
#   'tank',
#   'seeing',
#   'looks',
#   'performance',
#   'value',
#   'money',
#   '350',
#   'cc',
#   'segment',
#   '4',
#   'servicing',
#   'maintenance',
#   'service',
#   'provided',
#   'cheap',
#   'mean',
#   'personnel',
#   'knowledge',
#   'not',
#   'service',
#   'fee',
#   'screech',
#   'sound',
#   'not',
#   'solved',
#   'till',
#   'day',
#   'even',
#   'servicing',
#   '5',
#   'times',
#   'showroom',
#   'service',
#   'staffs',
#   'not',
#   'adequate',
#   'knowledge',
#   'service',
#   'bikes',
#   'described',
#   'user',
#   'manual',
#   'not',
#   'wash',
#   'digital',
#   'controls',
#   'pressurized',
#   'water',
#   'service',
#   'people',
#   'never',
#   'care',
#   'even',
#   'ask',
#   'lube',
#   'chain',
#   'lube',
#   'without',
#   'removing',
#   'dirt',
#   'without',
#   'cleaning',
#   'chain',
#   'service',
#   'quality',
#   'provided',
#   'high',
#   'end',
#   'poor',
#   'needs',
#   'improve',
#   'lot',
#   'maintenance',
#   'concerned',
#   'required',
#   'lube',
#   'chain',
#   'every',
#   '500',
#   'kms',
#   'spares',
#   'service',
#   'charges',
#   'cheaper',
#   'compared',
#   'brands',
#   'yet',
#   'needs',
#   'maintained',
#   'regularly',
#   'smooth',
#   'operation',
#   '5',
#   'pros',
#   'cons',
#   'pros',
#   '1',
#   'looks',
#   'beautiful',
#   'beast',
#   '2',
#   'performance',
#   'value',
#   'money',
#   '3',
#   'comfort',
#   'good',
#   'comfort',
#   'rider',
#   '4',
#   'spares',
#   'price',
#   '5',
#   'stability',
#   'high',
#   'speeds',
#   'long',
#   'rides',
#   '6',
#   'decent',
#   'mileage',
#   '7',
#   'killer',
#   'price',
#   'vfm',
#   'cons',
#   '1',
#   'service',
#   'poor',
#   'customer',
#   'service',
#   'technical',
#   'service',
#   '2',
#   'showroom',
#   'showrooms',
#   'busy',
#   'showcasing',
#   '200',
#   'rs',
#   'ns',
#   '150',
#   'easy',
#   'sell',
#   '3',
#   'market',
#   'accessories',
#   'difficult',
#   'find',
#   'expensive',
#   'buy',
#   '4',
#   'tank',
#   'capacity',
#   '5',
#   'fuel',
#   'indicator',
#   'not',
#   'accurate',
#   '2',
#   'points',
#   'reduced',
#   'first',
#   '150',
#   'kms',
#   'tank',
#   'full',
#   'remaining',
#   'points',
#   'gone',
#   'next',
#   '100',
#   'kms',
#   '6',
#   'pillion',
#   'seating',
#   'not',
#   'comfortable',
#   '7',
#   'poor',
#   'marketing',
#   'strategy'],
#  ['beast',
#   'beauty',
#   'not',
#   'looks',
#   'class',
#   'apart',
#   'also',
#   'beats',
#   'performance',
#   'value',
#   'money',
#   'would',
#   'rather',
#   'say',
#   'teenager',
#   'dressed',
#   'matured',
#   'attire',
#   'teenager',
#   'simile',
#   'ktm',
#   '390',
#   'engine',
#   'detuned',
#   'perfectly',
#   'chiseled',
#   'art',
#   'work',
#   'pal',
#   'lately',
#   'started',
#   'talking',
#   'lately',
#   'yes',
#   'gone',
#   'mad',
#   'literally'],
#  ['im',
#   'not',
#   'owner',
#   'ride',
#   'friends',
#   '400',
#   'several',
#   'times',
#   'not',
#   'owner',
#   'ride',
#   'friends',
#   '400',
#   'several',
#   'times',
#   'guy',
#   'takes',
#   'way',
#   'seriously',
#   'feeling',
#   'toward',
#   'machines',
#   'fell',
#   'great',
#   'affection',
#   'day',
#   'ride',
#   'best',
#   'option',
#   'go',
#   'looking',
#   'variants',
#   'different',
#   'companies',
#   'would',
#   'strongly',
#   'say',
#   'one',
#   'among',
#   'greatest',
#   'ride',
#   'indian',
#   'terrain',
#   'damn',
#   'mixture',
#   'good',
#   'bad',
#   'yeah',
#   'good',
#   'looks',
#   'hot',
#   'bold',
#   'good',
#   'mileage',
#   'performance',
#   'way',
#   'speedy',
#   'speedy'],
#  ['fall',
#   'love',
#   'looking',
#   'speed',
#   'nice',
#   'specially',
#   'designed',
#   'color',
#   'tyre',
#   'tubeless',
#   'speed',
#   'near',
#   '150',
#   'attractive',
#   'seat',
#   'comfortable',
#   'stylish',
#   'next',
#   'level',
#   'feeling',
#   'road',
#   '400',
#   'rate',
#   'something',
#   'highly',
#   'total',
#   'manage',
#   'seat',
#   'highway',
#   'comfortable',
#   'new',
#   'looking'],
#  ['boosts',
#   'using',
#   'since',
#   '2018',
#   'appreciate',
#   'performance',
#   'situation',
#   'whether',
#   'traveling',
#   'one',
#   'city',
#   'another',
#   'climatic',
#   'conditions',
#   'never',
#   'broke',
#   'trust',
#   'also',
#   'boost',
#   'confidence',
#   'road',
#   'time',
#   'putting',
#   'high',
#   'speed',
#   'meanwhile',
#   'person',
#   'wants',
#   'fun',
#   'ride',
#   'perfect'],
#  ['one',
#   'underrated',
#   'bikes',
#   'one',
#   'underrated',
#   'bikes',
#   'indian',
#   'motorbike',
#   'market',
#   'people',
#   'really',
#   'know',
#   'machine',
#   'loved',
#   'every',
#   'bit',
#   'minor',
#   'issue',
#   'negligible',
#   'main',
#   'issue',
#   'stock',
#   'mrf',
#   'tyres',
#   'really',
#   'bad',
#   'sometimes',
#   'room',
#   'improvement',
#   'service',
#   'persons',
#   'cooperative',
#   'helpful',
#   'overall',
#   'experience',
#   'awesome'],
#  ['value',
#   'money',
#   'complete',
#   'value',
#   'money',
#   'package',
#   'brakes',
#   'amazing',
#   'ride',
#   'quality',
#   'superb',
#   'gives',
#   'lot',
#   'confidence',
#   'pick',
#   'insane',
#   'not',
#   'need',
#   'push',
#   'hard',
#   'overall',
#   'fuel',
#   'economy',
#   'achieved',
#   '34kmpl',
#   'cooling',
#   'system',
#   'awesome',
#   '10',
#   'led',
#   'headlight',
#   'superb'],
#  ['review',
#   'one',
#   'men',
#   'best',
#   'get',
#   'love',
#   'passion',
#   'endurance',
#   'key',
#   'comfort',
#   'best',
#   'prefer',
#   'bikers',
#   'love',
#   'drive',
#   'best',
#   'beast',
#   'bikes',
#   'love',
#   'dominate',
#   'world',
#   'bikers',
#   'happy',
#   'get'],
#  ['lets',
#   'dominate',
#   'road',
#   'vfm',
#   'simply',
#   'awesome',
#   'no',
#   'doubt',
#   'one',
#   'best',
#   'segment',
#   'everything',
#   'good',
#   'thing',
#   'not',
#   'like',
#   'lower',
#   'rpm',
#   'stability',
#   'refined',
#   'smooth',
#   'higher',
#   'rpm',
#   'city',
#   'cruising',
#   '22',
#   '25',
#   'kmph',
#   'unstable',
#   'headlight',
#   'superb',
#   'include',
#   'gear',
#   'position',
#   'indicator',
#   'premium',
#   'segment'],
#  ['buy',
#   'not',
#   'like',
#   'pulsar',
#   'series',
#   'gives',
#   'problems',
#   'overtime',
#   'first',
#   'buying',
#   'experience',
#   'really',
#   'good',
#   'stay',
#   'pcmc',
#   'area',
#   '2',
#   'showroom',
#   'near',
#   'one',
#   'near',
#   'nigdi',
#   'showroom',
#   'shit',
#   'showroom',
# ...
#   '30',
#   '35',
#   'kmpl',
#   'approximate',
#   'road',
#   'price',
#   'de'],
#  ['sexy',
#   'dominating',
#   'stance',
#   'design',
#   'meets',
#   'eyes',
#   'massive',
#   'presence',
#   'dominating',
#   'low',
#   'slung',
#   'saddle',
#   'industrybest',
#   '43',
#   'mm',
#   'telescopic',
#   'fornt',
#   'forks',
#   'unique',
#   'dual',
#   'spring',
#   'mono',
#   'suspensino',
#   'make',
#   'effortless',
#   'riding',
#   'night',
#   'long',
#   'inspiration',
#   'leo',
#   'stance'],
#  ['best',
#   'right',
#   'love',
#   'better',
#   'terms',
#   'itz',
#   'cheaper',
#   'duke',
#   '390',
#   'much',
#   'better',
#   'bigger',
#   'fuel',
#   'tank',
#   'nice',
#   'types',
#   'seats',
#   'comfortable',
#   'duke390',
#   'daily',
#   'use',
#   'city',
#   'use',
#   'awesome',
#   'riding',
#   'long',
#   'distance',
#   'use',
#   'tricky',
#   'sometim'],
#  ['nice',
#   'awesome',
#   'new',
#   'looks',
#   'new',
#   'style',
#   'u',
#   'feel',
#   'good',
#   'good',
#   'speed',
#   'sporty',
#   'looking',
#   'balance',
#   'controlling',
#   'every',
#   'girl',
#   'watch',
#   'seeing',
#   'superb',
#   'stylist',
#   'better',
#   'pulsur',
#   'new',
#   'mobel',
#   'beter',
#   'sport',
#   'bikes',
#   'b'],
#  ['400',
#   'braking',
#   'suspension',
#   'mileage',
#   'ditching',
#   'usd',
#   'front',
#   'forks',
#   'set',
#   'seen',
#   'pulsar',
#   'cs400',
#   'concept',
#   '400',
#   'equips',
#   'telescopic',
#   'forks',
#   'front',
#   'mono',
#   'shock',
#   'absorbers',
#   'rear',
#   'muscular',
#   'body',
#   'rests',
#   'mrf',
#   'revz',
#   'c1',
#   'tyres',
#   'missing',
#   'metzelers',
#   'ktm',
#   'braking',
#   'power',
#   'non',
#   'abs',
#   'variant',
#   'comes',
#   'sin'],
#  ['amazing',
#   'rendering',
#   '400f',
#   'speculates',
#   'semi',
#   'faired',
#   'version',
#   'latest',
#   'power',
#   'cruiser',
#   'may',
#   'look',
#   'fairing',
#   'side',
#   'headlamp',
#   'region',
#   'lend',
#   'rider',
#   'protection',
#   'wind',
#   'blast',
#   'auto',
#   'showcased',
#   'fully',
#   'faired',
#   'version',
#   'engine',
#   '20'],
#  ['best',
#   'price',
#   'segment',
#   'looks',
#   'stunning',
#   'looks',
#   'powerful',
#   'led',
#   'headlamps',
#   'led',
#   'indicators',
#   'led',
#   'tail',
#   'light',
#   'experience',
#   'best',
#   'looking',
#   'motorcycle',
#   '400cc',
#   'segment',
#   'handling',
#   'superb',
#   'wide',
#   'handle',
#   'bar',
#   'easily',
#   'flick',
#   'traff'],
#  ['dominator',
#   'love',
#   '400',
#   'hand',
#   'consist',
#   '1453',
#   'mm',
#   'not',
#   'much',
#   'different',
#   'mojo',
#   'would',
#   'prove',
#   'equally',
#   'stable',
#   'dual',
#   'channel',
#   'abs',
#   'slipper',
#   'clutch',
#   '400',
#   '34',
#   '5',
#   'bhp',
#   'motor',
#   'beautiful',
#   'led',
#   'headlamps',
#   'tiny',
#   'visor',
#   'seat',
#   'broad'],
#  ['pular',
#   'launched',
#   '400',
#   'naked',
#   'racing',
#   'cheap',
#   'front',
#   'ktm390',
#   'powerfull',
#   'engine',
#   'comfortable',
#   'ktm',
#   'supercool',
#   'seem',
#   'like',
#   'elder',
#   'brother',
#   'ns',
#   '200',
#   'slipper',
#   'clutch',
#   'added',
#   'enjoy',
#   'thrill',
#   '373',
#   'cc',
#   'powerful',
#   'engine',
#   'might',
#   'cross',
#   '180',
#   'kmph',
#   'easily',
#   'silent'],
#  ['dominor',
#   '400',
#   'really',
#   'nice',
#   'good',
#   'look',
#   'like',
#   'lion',
#   'cheeta',
#   'importent',
#   'x',
#   'hunt',
#   'sound',
#   'mainly',
#   'one',
#   'minite',
#   'speed',
#   'incresd',
#   '150',
#   'break',
#   'system',
#   'really',
#   'good',
#   'main',
#   'light',
#   'led',
#   'lemp',
#   'nice',
#   'like'],
#  ['hi',
#   'friends',
#   'gonna',
#   'tell',
#   'splendid',
#   'super',
#   'shape',
#   'one',
#   'ride',
#   'really',
#   'really',
#   'fall',
#   'love',
#   'day',
#   'night',
#   'dream',
#   'buy',
#   'extraordinary',
#   'features',
#   'like',
#   'triple',
#   'spark',
#   'engine',
#   'f'],
#  ['pure',
#   'power',
#   'following',
#   'purly',
#   'built',
#   'cs400',
#   'concept',
#   '400',
#   'retains',
#   'styling',
#   'prototype',
#   'revealed',
#   'publically',
#   '2014',
#   'auto',
#   'expo',
#   'name',
#   'coming',
#   'frm',
#   'spanish',
#   'word',
#   'means',
#   'excel',
#   'exceed',
#   'power',
#   'combines',
#   'adventure',
#   'crui'],
#  ['best',
#   'looks',
#   'performance',
#   'recent',
#   'accident',
#   'restricted',
#   'scooters',
#   'real',
#   'seems',
#   'grab',
#   'attention',
#   'launched',
#   'didnt',
#   'change',
#   'rather',
#   'feels',
#   'better',
#   'real',
#   'even',
#   'though',
#   'gives',
#   'good',
#   'fight',
#   'dominor400',
#   'sportiness',
#   'premium',
#   'feel',
#   'would',
#   'real',
#   'work',
#   'great',
#   'people'],
#  ['400',
#   'good',
#   'evening',
#   'guys',
#   'today',
#   'give',
#   'drawback',
#   'reviw',
#   'dominer',
#   '400',
#   'like',
#   'looks',
#   'totaly',
#   'different',
#   'power',
#   'torque',
#   'not',
#   'much',
#   'good',
#   '373cc',
#   'engine',
#   'ktm',
#   'rc',
#   'duke',
#   'also',
#   '373cc',
#   'engine'],
#  ['awesome',
#   'high',
#   'performance',
#   'handling',
#   'breaking',
#   'awesome',
#   'due',
#   'abs',
#   'optional',
#   'top',
#   'speed',
#   '148',
#   'kmh',
#   'go',
#   'price',
#   '1',
#   '60',
#   'lac',
#   'road',
#   'price',
#   'abs',
#   'totally',
#   'valve',
#   'money',
#   '400cc',
#   'fi',
#   'carburetor',
#   'engine'],
#  ['400',
#   'magic',
#   'great',
#   'everything',
#   'best',
#   'not',
#   'great',
#   'mileage',
#   'review',
#   'style',
#   'feel',
#   'full',
#   'comfort',
#   'style',
#   'looks',
#   'enormous',
#   'great',
#   'real',
#   'opposed',
#   'photos',
#   'alloy',
#   'wheels',
#   'makes',
#   'full',
#   'sporty',
#   'look',
#   'wise',
#   'headlamp',
#   'additiona'],
#  ['power',
#   'power',
#   '400',
#   'name',
#   'anything',
#   'best',
#   'mid',
#   'range',
#   'metre',
#   'range',
#   '100000',
#   '2',
#   'lacs',
#   '400',
#   'cc',
#   'engine',
#   'might',
#   'work',
#   'power',
#   'good',
#   'speed',
#   'work',
#   'road',
#   'speed',
#   '150',
#   'pr',
#   'h',
#   'sohail',
#   'actually',
#   'prices'],
#  ['best',
#   'buy',
#   'money',
#   'best',
#   'buy',
#   '1',
#   '50',
#   '000',
#   'bought',
#   'abs',
#   'version',
#   'running',
#   'absolutely',
#   'fine',
#   'little',
#   'worried',
#   'totally',
#   'new',
#   'thing',
#   'awesome',
#   'riding',
#   '1000',
#   'kms',
#   'think',
#   'give',
#   'review',
#   'pros',
#   'great',
#   'pick'],
#  ['not',
#   'satisfied',
#   'dominor',
#   '400',
#   'worst',
#   'comparing',
#   'sports',
#   'top',
#   'speed',
#   '148',
#   'kmph',
#   '379',
#   '3',
#   'cc',
#   'single',
#   'cylinder',
#   'actually',
#   'sports',
#   'didnt',
#   'performe',
#   'well',
#   '6',
#   'gears',
#   'seating',
#   'not',
#   'comfortable',
#   'colours',
#   'also',
#   'not',
#   'attractive',
#   'touches',
#   '100',
#   '8',
#   '45',
#   'sec',
#   'not',
#   'good',
#   'comparing',
#   'wit'],
#  ['sexy',
#   '400',
#   'smart',
#   'bikes',
#   'awsome',
#   'look',
#   'brilient',
#   'controls',
#   'also',
#   'okay',
#   'feul',
#   'low',
#   'types',
#   'bikes',
#   '15',
#   '20',
#   'kmpl',
#   'mailege',
#   '400',
#   '28',
#   'kmpl',
#   'mailege',
#   'means',
#   'fominae',
#   '400',
#   'brilient',
#   'fuel',
#   'mailege',
#   'speed'],
#  ['best',
#   'indian',
#   '400',
#   'hey',
#   'guys',
#   'real',
#   'monster',
#   'machine',
#   'india',
#   '35',
#   'nm',
#   'torque',
#   'best',
#   'price',
#   '2',
#   'lakhs',
#   'average',
#   'good',
#   '30',
#   '32',
#   'awesome',
#   'riding',
#   'comfort',
#   'bajajs',
#   'first',
#   'doesnt',
#   'make',
#   'gear',
#   'shift',
#   'noice',
#   'petrol',
#   'tank',
#   'capacity',
#   'good',
#   '13',
#   'ltrs',
#   'driving',
#   'machine',
#   '120',
#   'smooth'],
#  ['super',
#   'cruiser',
#   'bought',
#   'new',
#   'beast',
#   'roll',
#   'throttle',
#   'done',
#   '0',
#   '50',
#   '3',
#   '2',
#   'seconds',
#   '0',
#   '100',
#   '7',
#   '4',
#   'seconds',
#   'new',
#   'abs',
#   'dual',
#   'chanel',
#   'turn',
#   'confidently',
#   'new',
#   'full',
#   'heglights',
#   'pretty',
#   'monoshoccer',
#   'liquid',
#   'cooling',
#   'better',
#   'c'],
#  ['400',
#   'bought',
#   '3',
#   'feb',
#   '2017',
#   'rided',
#   'almost',
#   '1700',
#   'km',
#   'till',
#   'date',
#   'certain',
#   'things',
#   'like',
#   'things',
#   'point',
#   'view',
#   'still',
#   'lack',
#   'behind',
#   'best',
#   'thing',
#   'no',
#   'doubt',
#   'led',
#   'headlambs',
#   'look',
#   'attractive',
#   'gain',
#   'att'],
#  ['dominating',
#   'power',
#   'cruising',
#   'one',
#   'best',
#   'power',
#   'sports',
#   'cruiser',
#   'comes',
#   'anprice',
#   '1',
#   '72',
#   '000',
#   'targetting',
#   'royal',
#   'enfield',
#   'shares',
#   'probablly',
#   'going',
#   'dominate',
#   'power',
#   'segment',
#   'aho',
#   'lamp',
#   'dual',
#   'dial',
#   'chunky',
#   '43',
#   'mm',
#   'fork',
#   'wise',
#   'also',
#   'comes',
#   'dual',
#   'cha'],
#  ['400',
#   'want',
#   'tell',
#   'specification',
#   'loud',
#   'sounds',
#   'way',
#   'perfermonce',
#   'road',
#   'grip',
#   'quite',
#   'good',
#   'good',
#   'max',
#   'power',
#   '8000rpm',
#   '6500',
#   'torque',
#   'smooth',
#   'clutch',
#   'overall',
#   'performance',
#   'good'],
#  ['awesome',
#   'power',
#   'pune',
#   'based',
#   'bikemaker',
#   'premium',
#   'flagship',
#   'power',
#   'cruiser',
#   'launched',
#   'attractive',
#   'price',
#   'rs',
#   '1',
#   '36',
#   'lakh',
#   'ex',
#   'showroom',
#   'delhi',
#   'december',
#   'last',
#   'year',
#   'badged',
#   'powerful',
#   'available',
#   '42',
#   'cities',
#   'country',
#   'february',
#   '2017',
#   'company'],
#  ['best',
#   'price',
#   'segment',
#   '400',
#   'abs',
#   'best',
#   'price',
#   'range',
#   'anyone',
#   'planning',
#   'buy',
#   'without',
#   'abs',
#   'put',
#   'extra',
#   'money',
#   'buy',
#   'abs',
#   'version',
#   'abs',
#   'really',
#   'helps',
#   'braking',
#   'design',
#   'looks',
#   'fabulous',
#   'braking',
#   'performance',
#   'best',
#   'class',
#   'headlight'],
#  ['400',
#   'nice',
#   '400',
#   'nice',
#   'interms',
#   'pickup',
#   'power',
#   'design',
#   'efficient',
#   'engine',
#   'meets',
#   'current',
#   'demands',
#   'youth',
#   'lookwise',
#   'suspension',
#   'nice',
#   'confortable',
#   'front',
#   'look',
#   'nice',
#   'makes',
#   'look',
#   'stunning',
#   'seat',
#   'enough',
#   'space'],
#  ['great',
#   'performance',
#   'naked',
#   'must',
#   'say',
#   'value',
#   'money',
#   'ridden',
#   'upto',
#   '150',
#   'kmph',
#   'track',
#   'felt',
#   'almost',
#   'nil',
#   'vibration',
#   'throught',
#   'entire',
#   'rpm',
#   'range',
#   'engine',
#   'much',
#   'refined',
#   'compared',
#   'others',
#   'engines',
#   'dual',
#   'abs',
#   'slipper',
#   'clutch',
#   'led',
#   'headlamp',
#   'classic',
#   'tail',
#   'light',
#   'co',
#   'fortabl'],
#  ['super',
#   'hi',
#   'friends',
#   'using',
#   'past',
#   'three',
#   'months',
#   'best',
#   'found',
#   'really',
#   'awesome',
#   'given',
#   'bellow',
#   'features',
#   'nearly',
#   'arount1',
#   '5',
#   'lakh',
#   'rupees',
#   'speed',
#   'ride',
#   '154',
#   'kmph',
#   'visual',
#   'appearance',
#   'good',
#   'mileage',
#   'ge'],
#  ['sexy',
#   'dad',
#   'gifted',
#   '400',
#   'birthday',
#   'sport',
#   'great',
#   'power',
#   'mileage',
#   'also',
#   'better',
#   'best',
#   'comfort',
#   'best',
#   'operation',
#   'road',
#   'grip',
#   'also',
#   'good',
#   'make',
#   'good',
#   'feel',
#   'sound',
#   'great',
#   'go',
#   'ride',
#   'sunday',
#   'bik'],
#  ['awsome',
#   'good',
#   'pickup',
#   'strong',
#   'well',
#   'designed',
#   'comfartable',
#   'engine',
#   '373',
#   '3',
#   'cc',
#   'gives',
#   'power',
#   'classic',
#   'look',
#   'attract',
#   'people',
#   'exhaust',
#   'around',
#   'attract',
#   'people',
#   'towards',
#   'us',
#   'drive',
#   'fell',
#   'like',
#   'royal',
#   'speed',
#   'g'],
#  ['awesome',
#   '400',
#   'good',
#   '400cc',
#   'power',
#   'makes',
#   'king',
#   'good',
#   'pickup',
#   'good',
#   'speed',
#   'fast',
#   'bikes',
#   'win',
#   'year',
#   'year',
#   'next',
#   'year',
#   'user',
#   'must',
#   'say',
#   'good',
#   'price',
#   'g'],
#  ['awsum',
#   'awsum',
#   'features',
#   'swing',
#   'leg',
#   'first',
#   'thing',
#   'notice',
#   'no',
#   'light',
#   '182',
#   'kg',
#   'kerb',
#   'weight',
#   'weight',
#   'seems',
#   'magically',
#   'disappear',
#   'soon',
#   'move',
#   'flat',
#   'wide',
#   'handlebar',
#   'comfortable',
#   'split',
#   'dual',
#   'seat',
#   'crawling',
#   'traffic',
#   '400',
#   'not',
#   'make'],
#  ['400',
#   'last',
#   'week',
#   'purchased',
#   '400',
#   'nearest',
#   'dealer',
#   'purchased',
#   'good',
#   'looks',
#   'good',
#   'features',
#   'powerful',
#   'good',
#   'mileage',
#   'comfort',
#   'fuel',
#   'tank',
#   '13',
#   'litres',
#   '373cc',
#   'single',
#   'cyclinder',
#   'built',
#   'top',
#   'speed',
#   '155km',
#   'h',
#   'bik'],
#  ['budget',
#   'product',
#   'exotic',
#   'power',
#   'budgetd',
#   'product',
#   'great',
#   'power',
#   'would',
#   'say',
#   'budget',
#   'no',
#   'avilable',
#   'used',
#   'really',
#   'liked',
#   'comes',
#   '373',
#   'cc',
#   'enough',
#   'rider',
#   'really',
#   'loved',
#   'ita',
#   'enough',
#   'ride',
#   'lot',
#   'still',
#   'didnt',
#   'fell',
#   'spinal',
#   'p'],
#  ['awesome',
#   'name',
#   'name',
#   'performence',
#   'bajaja',
#   '400',
#   'ver',
#   'good',
#   'bick',
#   'brothe',
#   'recently',
#   'brought',
#   'ride',
#   'picup',
#   'simply',
#   'awesome',
#   'really',
#   'got',
#   'sexy',
#   'desing',
#   'really',
#   'looks',
#   'good',
#   'motion',
#   'smouth'],
#  ['dominor',
#   '400',
#   'ride',
#   'not',
#   'get',
#   'feel',
#   'riding',
#   'sports',
#   'appearance',
#   'rider',
#   'comforts',
#   'move',
#   'fast',
#   'good',
#   'pick',
#   'not',
#   'convinient',
#   'stunting',
#   'pulsar',
#   '200ns',
#   'since',
#   'high',
#   'centre',
#   'gravity',
#   'compared',
#   'pulsar',
#   '200ns',
#   'ba'],
#  ['adinath',
#   'gade',
#   'family',
#   'gifted',
#   '400',
#   'brother',
#   'birthday',
#   'sports',
#   'great',
#   'power',
#   'mileage',
#   'also',
#   'good',
#   'best',
#   'comfort',
#   'best',
#   'control',
#   'road',
#   'grip',
#   'also',
#   'good',
#   'make',
#   'good',
#   'feel',
#   'sound',
#   'great',
#   'go',
#   'ride',
#   'sunday',
#   'thi'],
#  ['good',
#   'look',
#   '400',
#   'hi',
#   'friends',
#   '400',
#   'power',
#   'cruise',
#   '400cc',
#   'bikes',
#   'rs',
#   '1',
#   '45',
#   'lakhs',
#   'perfect',
#   'look',
#   'power',
#   'extraordinary',
#   'dual',
#   'handed',
#   'abs',
#   'system',
#   'sleepper',
#   'clutch',
#   'mostly',
#   'suitable',
#   'long',
#   'rides',
#   'ride',
#   'slightly',
#   'give'],
#  ['400cc',
#   'impactable',
#   'series',
#   'poduct',
#   'totally',
#   'different',
#   'product',
#   'maintenance',
#   'osm',
#   'develops',
#   'osm',
#   'variation',
#   'sound',
#   'cost',
#   'better',
#   'not',
#   'bad',
#   'bikes',
#   'like',
#   'duke',
#   'etc',
#   'type',
#   'look',
#   'like',
#   'ktm',
#   'duke',
#   '200',
#   'b'],
#  ['dominor',
#   '400',
#   'pros',
#   'stylish',
#   'per',
#   'manual',
#   'see',
#   'design',
#   'based',
#   'male',
#   'lion',
#   'thick',
#   'mane',
#   'around',
#   'head',
#   'sounds',
#   'refined',
#   'sounds',
#   'likes',
#   'sports',
#   'rev',
#   'best',
#   'head',
#   'light',
#   'seen',
#   'cons',
#   'seating',
#   'rear',
#   'seat',
#   'literally',
#   'worst',
#   'seat'],
#  ['400',
#   'super',
#   'guys',
#   'new',
#   '400cc',
#   'best',
#   'market',
#   'trending',
#   'features',
#   'simply',
#   'amazing',
#   'nstalled',
#   'abs',
#   'technology',
#   'known',
#   'anti',
#   'lock',
#   'breaking',
#   'system',
#   'abled',
#   '2',
#   'tube',
#   'less',
#   'tyres',
#   'gives',
#   'pretty',
#   'good'],
#  ['400',
#   'october',
#   '2017',
#   'dubbed',
#   'spanish',
#   'word',
#   'means',
#   'access',
#   '400',
#   'brings',
#   'pranks',
#   'youtube',
#   'full',
#   'form',
#   'users',
#   'comfort',
#   'horrible',
#   'fun',
#   'run',
#   'machine',
#   'launched',
#   'december',
#   '2006',
#   'capable',
#   'characters',
#   'presented',
#   'affordable',
#   'power',
#   'cru'],
#  ['superb',
#   '2017',
#   'hi',
#   'guys',
#   'motocompany',
#   'lauched',
#   'new',
#   'new',
#   'dominor',
#   '400',
#   'recently',
#   'market',
#   'thr',
#   'sold',
#   'market',
#   'beacsue',
#   'looked',
#   'design',
#   'excllent',
#   'quality',
#   'looking',
#   'sexy',
#   'lookedthe',
#   'bulid',
#   'quality',
#   'good',
#   'design',
#   'lookinh',
#   'awesome'],
#  ['beast',
#   'not',
#   'mileage',
#   'truly',
#   'really',
#   'beast',
#   'guarantees',
#   'good',
#   'road',
#   'grip',
#   'awesome',
#   'comfortness',
#   'superb',
#   'road',
#   'trips',
#   'mileage',
#   'not',
#   'good',
#   'otherwise',
#   'really',
#   'good',
#   'purchase',
#   'looks',
#   'suspension',
#   'engine',
#   'braking',
#   'system',
#   'top',
#   'notch',
#   '400cc',
#   'beast',
#   'always',
#   'ensure'],
#  ['dominor',
#   '400',
#   'hello',
#   'firends',
#   'recently',
#   'purchase',
#   'dominor',
#   '400',
#   'good',
#   'looking',
#   'ever',
#   'milage',
#   'poor',
#   'company',
#   'says',
#   '35',
#   '40',
#   'high',
#   'way',
#   'try',
#   '30',
#   'km',
#   'per',
#   'litter',
#   'bile',
#   'graphics',
#   'good',
#   'style',
#   'attractive',
#   'engine',
#   'power',
#   'full',
#   'pick',
#   'high',
#   'balanced'],
#  ['era',
#   'power',
#   'riding',
#   'quite',
#   'bikes',
#   'owned',
#   'friends',
#   'couple',
#   'years',
#   'reading',
#   'magazines',
#   'watching',
#   'countless',
#   'videos',
#   'tube',
#   'ready',
#   'purchase',
#   'first',
#   'wanted',
#   'make',
#   'sure',
#   'bought',
#   'perfect',
#   'anything',
#   'tough',
#   'find'],
#  ...]

# %%
from gensim import corpora
dictionary = corpora.Dictionary(text_data)
corpus = [dictionary.doc2bow(text) for text in text_data]

# %%
import gensim
NUM_TOPICS = 20
ldamodel = gensim.models.ldamodel.LdaModel(corpus, num_topics = NUM_TOPICS, id2word=dictionary)
ldamodel.save('model5.gensim')

# %%
topics = ldamodel.print_topics(num_words=8)

# %%
for topic in topics:
    print(topic)
# Out:
# (0, '0.021*"400" + 0.014*"good" + 0.011*"best" + 0.009*"ride" + 0.008*"not" + 0.008*"nice" + 0.008*"look" + 0.007*"riding"')
# (1, '0.015*"400" + 0.015*"good" + 0.013*"great" + 0.012*"not" + 0.010*"best" + 0.009*"ride" + 0.009*"power" + 0.007*"abs"')
# (2, '0.013*"really" + 0.010*"not" + 0.009*"good" + 0.008*"ride" + 0.007*"feel" + 0.006*"first" + 0.006*"like" + 0.006*"love"')
# (3, '0.028*"400" + 0.018*"like" + 0.013*"power" + 0.012*"best" + 0.011*"good" + 0.011*"not" + 0.010*"engine" + 0.010*"mileage"')
# (4, '0.020*"good" + 0.015*"not" + 0.012*"400" + 0.011*"mileage" + 0.011*"also" + 0.010*"power" + 0.010*"like" + 0.010*"best"')
# (5, '0.023*"400" + 0.015*"good" + 0.011*"speed" + 0.011*"power" + 0.010*"not" + 0.009*"riding" + 0.008*"looks" + 0.008*"like"')
# (6, '0.030*"good" + 0.022*"400" + 0.018*"not" + 0.010*"best" + 0.008*"also" + 0.007*"bikes" + 0.007*"riding" + 0.007*"engine"')
# (7, '0.018*"good" + 0.015*"engine" + 0.013*"400" + 0.007*"powerful" + 0.007*"price" + 0.007*"design" + 0.007*"new" + 0.006*"feel"')
# (8, '0.016*"not" + 0.013*"400" + 0.012*"engine" + 0.011*"good" + 0.007*"like" + 0.007*"also" + 0.007*"best" + 0.006*"speed"')
# (9, '0.023*"good" + 0.023*"400" + 0.019*"not" + 0.017*"best" + 0.008*"1" + 0.008*"bikes" + 0.007*"price" + 0.007*"engine"')
# (10, '0.039*"good" + 0.034*"400" + 0.020*"also" + 0.015*"best" + 0.012*"mileage" + 0.011*"not" + 0.010*"great" + 0.008*"really"')
# (11, '0.042*"400" + 0.012*"like" + 0.011*"engine" + 0.009*"not" + 0.009*"power" + 0.009*"price" + 0.008*"one" + 0.008*"1"')
# (12, '0.025*"400" + 0.017*"good" + 0.011*"bikes" + 0.010*"one" + 0.009*"best" + 0.009*"awesome" + 0.009*"engine" + 0.008*"ride"')
# (13, '0.017*"not" + 0.013*"400" + 0.010*"riding" + 0.010*"experience" + 0.010*"good" + 0.008*"service" + 0.008*"ride" + 0.007*"like"')
# (14, '0.051*"good" + 0.013*"400" + 0.012*"best" + 0.012*"not" + 0.010*"awesome" + 0.010*"looks" + 0.009*"also" + 0.009*"look"')
# (15, '0.015*"good" + 0.010*"ride" + 0.009*"best" + 0.008*"really" + 0.008*"buy" + 0.007*"like" + 0.007*"looks" + 0.007*"400"')
# (16, '0.025*"good" + 0.012*"400" + 0.011*"ride" + 0.011*"like" + 0.009*"not" + 0.008*"one" + 0.008*"mileage" + 0.008*"looks"')
# (17, '0.011*"riding" + 0.010*"not" + 0.010*"good" + 0.009*"400" + 0.008*"mileage" + 0.008*"looks" + 0.007*"also" + 0.007*"engine"')
# (18, '0.020*"400" + 0.017*"not" + 0.015*"power" + 0.012*"good" + 0.010*"abs" + 0.010*"engine" + 0.009*"like" + 0.008*"look"')
# (19, '0.015*"400" + 0.014*"best" + 0.012*"not" + 0.010*"ride" + 0.008*"engine" + 0.008*"one" + 0.008*"power" + 0.008*"1"')

# %%
topics
# Out:
# [(0,
#   '0.021*"400" + 0.014*"good" + 0.011*"best" + 0.009*"ride" + 0.008*"not" + 0.008*"nice" + 0.008*"look" + 0.007*"riding"'),
#  (1,
#   '0.015*"400" + 0.015*"good" + 0.013*"great" + 0.012*"not" + 0.010*"best" + 0.009*"ride" + 0.009*"power" + 0.007*"abs"'),
#  (2,
#   '0.013*"really" + 0.010*"not" + 0.009*"good" + 0.008*"ride" + 0.007*"feel" + 0.006*"first" + 0.006*"like" + 0.006*"love"'),
#  (3,
#   '0.028*"400" + 0.018*"like" + 0.013*"power" + 0.012*"best" + 0.011*"good" + 0.011*"not" + 0.010*"engine" + 0.010*"mileage"'),
#  (4,
#   '0.020*"good" + 0.015*"not" + 0.012*"400" + 0.011*"mileage" + 0.011*"also" + 0.010*"power" + 0.010*"like" + 0.010*"best"'),
#  (5,
#   '0.023*"400" + 0.015*"good" + 0.011*"speed" + 0.011*"power" + 0.010*"not" + 0.009*"riding" + 0.008*"looks" + 0.008*"like"'),
#  (6,
#   '0.030*"good" + 0.022*"400" + 0.018*"not" + 0.010*"best" + 0.008*"also" + 0.007*"bikes" + 0.007*"riding" + 0.007*"engine"'),
#  (7,
#   '0.018*"good" + 0.015*"engine" + 0.013*"400" + 0.007*"powerful" + 0.007*"price" + 0.007*"design" + 0.007*"new" + 0.006*"feel"'),
#  (8,
#   '0.016*"not" + 0.013*"400" + 0.012*"engine" + 0.011*"good" + 0.007*"like" + 0.007*"also" + 0.007*"best" + 0.006*"speed"'),
#  (9,
#   '0.023*"good" + 0.023*"400" + 0.019*"not" + 0.017*"best" + 0.008*"1" + 0.008*"bikes" + 0.007*"price" + 0.007*"engine"'),
#  (10,
#   '0.039*"good" + 0.034*"400" + 0.020*"also" + 0.015*"best" + 0.012*"mileage" + 0.011*"not" + 0.010*"great" + 0.008*"really"'),
#  (11,
#   '0.042*"400" + 0.012*"like" + 0.011*"engine" + 0.009*"not" + 0.009*"power" + 0.009*"price" + 0.008*"one" + 0.008*"1"'),
#  (12,
#   '0.025*"400" + 0.017*"good" + 0.011*"bikes" + 0.010*"one" + 0.009*"best" + 0.009*"awesome" + 0.009*"engine" + 0.008*"ride"'),
#  (13,
#   '0.017*"not" + 0.013*"400" + 0.010*"riding" + 0.010*"experience" + 0.010*"good" + 0.008*"service" + 0.008*"ride" + 0.007*"like"'),
#  (14,
#   '0.051*"good" + 0.013*"400" + 0.012*"best" + 0.012*"not" + 0.010*"awesome" + 0.010*"looks" + 0.009*"also" + 0.009*"look"'),
#  (15,
#   '0.015*"good" + 0.010*"ride" + 0.009*"best" + 0.008*"really" + 0.008*"buy" + 0.007*"like" + 0.007*"looks" + 0.007*"400"'),
#  (16,
#   '0.025*"good" + 0.012*"400" + 0.011*"ride" + 0.011*"like" + 0.009*"not" + 0.008*"one" + 0.008*"mileage" + 0.008*"looks"'),
#  (17,
#   '0.011*"riding" + 0.010*"not" + 0.010*"good" + 0.009*"400" + 0.008*"mileage" + 0.008*"looks" + 0.007*"also" + 0.007*"engine"'),
#  (18,
#   '0.020*"400" + 0.017*"not" + 0.015*"power" + 0.012*"good" + 0.010*"abs" + 0.010*"engine" + 0.009*"like" + 0.008*"look"'),
#  (19,
#   '0.015*"400" + 0.014*"best" + 0.012*"not" + 0.010*"ride" + 0.008*"engine" + 0.008*"one" + 0.008*"power" + 0.008*"1"')]

# %%
df_topics = pd.DataFrame(topics,columns=['Index','topic'])

# %%
df_topics.to_csv('C:/All/Data/topics.csv')
